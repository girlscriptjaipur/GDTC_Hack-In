# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_excel('https://query.data.world/s/msbnsoqfh4vzsjnwqkd5n3zrcsuzct')

# %%
df.head() #It's messed up We can see clearly the 3rd index of row is actually the column name
# Out:
#   India General Elections 2014 - Complete list of candidate level votes sourced from election commission website eciresults.nic.in  \
# 0                                                NaN
# 1  Powered by Whizz WiFi - Social analytics and W...
# 2                                                NaN
# 3                                              State
# 4                          Andaman & Nicobar Islands
#
#                   Unnamed: 1       Unnamed: 2              Unnamed: 3  \
# 0                        NaN              NaN                     NaN
# 1                        NaN              NaN                     NaN
# 2                        NaN              NaN                     NaN
# 3                   Assembly        Candidate                   Party
# 4  Andaman & Nicobar Islands  BISHNU PADA RAY  Bharatiya Janata Party
#
#   Unnamed: 4
# 0        NaN
# 1        NaN
# 2        NaN
# 3      Votes
# 4      90969

# %%
df = df.rename(columns=df.iloc[3])
df.head()
# Out:
#                                                State  \
# 0                                                NaN
# 1  Powered by Whizz WiFi - Social analytics and W...
# 2                                                NaN
# 3                                              State
# 4                          Andaman & Nicobar Islands
#
#                     Assembly        Candidate                   Party  Votes
# 0                        NaN              NaN                     NaN    NaN
# 1                        NaN              NaN                     NaN    NaN
# 2                        NaN              NaN                     NaN    NaN
# 3                   Assembly        Candidate                   Party  Votes
# 4  Andaman & Nicobar Islands  BISHNU PADA RAY  Bharatiya Janata Party  90969

# %%
df = df.iloc[4:,:]
df.head()
# Out:
#                        State                   Assembly           Candidate  \
# 4  Andaman & Nicobar Islands  Andaman & Nicobar Islands     BISHNU PADA RAY
# 5  Andaman & Nicobar Islands  Andaman & Nicobar Islands  KULDEEP RAI SHARMA
# 6  Andaman & Nicobar Islands  Andaman & Nicobar Islands      SANJAY MESHACK
# 7  Andaman & Nicobar Islands  Andaman & Nicobar Islands        ANITA MONDAL
# 8  Andaman & Nicobar Islands  Andaman & Nicobar Islands             K.G.DAS
#
#                                 Party  Votes
# 4              Bharatiya Janata Party  90969
# 5            Indian National Congress  83157
# 6                     Aam Aadmi Party   3737
# 7        All India Trinamool Congress   2283
# 8  Communist Party of India (Marxist)   1777

# %% [markdown]
# ### Let's me explain this data to you:
#
# __State : This is state of our country which has many Assemblies__
#
# __Assembly: Smallest Piece where which election will happen.__
#
# __Candidate : Is the name of the candidate__
#
# __Party: This give insights to which party the person belongs to. (Independent if no party)__
#
# __Votes: It's not the total votes. IT'S THE MARGIN WITH WHICH THE WINNER WON__

# %% [markdown]
# #### Can you answer the following questions and as a prove provide visualizations for me?

# %% [markdown]
# #### __Which State has maximum Assembly?__

# %%
df['State'].unique()
df.groupby('State').count()
# uttarpradesh has maximum assembly
# Out:
#                            Assembly  Candidate  Party  Votes
# State
# Andaman & Nicobar Islands        16         16     16     16
# Andhra Pradesh                  640        640    640    640
# Arunachal Pradesh                13         13     13     13
# Assam                           176        176    176    176
# Bihar                           647        647    647    647
# Chandigarh                       18         18     18     18
# Chhattisgarh                    222        222    222    222
# Dadra & Nagar Haveli             12         12     12     12
# Daman & Diu                       5          5      5      5
# Goa                              21         21     21     21
# Gujarat                         360        360    360    360
# Haryana                         240        240    240    240
# Himachal Pradesh                 42         42     42     42
# Jammu & Kashmir                  83         83     83     83
# Jharkhand                       254        254    254    254
# Karnataka                       462        462    462    462
# Kerala                          289        289    289    289
# Lakshadweep                       7          7      7      7
# Madhya Pradesh                  407        407    407    407
# Maharashtra                     945        945    945    945
# Manipur                          20         20     20     20
# Meghalaya                        12         12     12     12
# Mizoram                           4          4      4      4
# NCT OF Delhi                    157        157    157    157
# Nagaland                          4          4      4      4
# Odisha                          217        217    217    217
# Puducherry                       31         31     31     31
# Punjab                          266        266    266    266
# Rajasthan                       345        345    345    345
# Sikkim                            7          7      7      7
# Tamil Nadu                      884        884    884    884
# Tripura                          27         27     27     27
# Uttar Pradesh                  1368       1368   1368   1368
# Uttarakhand                      79         79     79     79
# West Bengal                     514        514    514    514

# %%
df1 = df.groupby(['State']).count()
df1.plot(kind='line',figsize=(15,7))
plt.ylabel("no.of Assembly")
plt.xlabel("States")
plt.show()

# %%
df1.head()
# Out:
#                            Assembly  Candidate  Party  Votes
# State
# Andaman & Nicobar Islands        16         16     16     16
# Andhra Pradesh                  640        640    640    640
# Arunachal Pradesh                13         13     13     13
# Assam                           176        176    176    176
# Bihar                           647        647    647    647

# %% [markdown]
# #### __Visualize the seat share of parties (Find the best way to present it)?__

# %%
df2=df.groupby('Party').count()
df2
# Out:
#                                                     State  Assembly  \
# Party
# AARAKSHAN VIRODHI PARTY                                 3         3
# AJSU Party                                             10        10
# Aadijan Mukti Sena                                      1         1
# Aadivasi Sena Party                                     2         2
# Aam Aadmi Party                                       432       432
# Aam Janata Party                                        1         1
# Aama Odisha Party                                       9         9
# Aazadi Ka Antim Aandolan Dal                            1         1
# Adarsh Manavtawadi Party                                1         1
# Adarsh Rashtriya Vikas Party                            7         7
# Adarsh Samaj Party                                      1         1
# Agar Jan Party                                          2         2
# Akhand Bharat Samaj Party                               1         1
# Akhil Bharat Hindu Mahasabha                            8         8
# Akhil Bharatiya Ashok Sena                              1         1
# Akhil Bharatiya Congress Dal (Ambedkar)                 2         2
# Akhil Bharatiya Hind Kranti Party                       1         1
# Akhil Bharatiya Jan Sangh                               4         4
# Akhil Bharatiya Manavata Paksha                         1         1
# Akhil Bharatiya Muslim League (Secular)                 5         5
# Akhil Bharatiya Rajarya Sabha                           1         1
# Akhil Bharatiya Samajwadi Congress                      1         1
# Akhil Bharatiya Shivsena Rashtrawadi                    1         1
# Akhil Bhartiya Aamjan Party                             1         1
# Akhil Bhartiya Jharkhand Party                          3         3
# Akhil Bhartiya Mithila Party                            2         2
# Akhil Bhartiya Vikas Congress Party                     1         1
# Akhil Rashtrawadi Party                                 1         1
# Al-Hind Party                                           4         4
# All India Anna Dravida Munnetra Kazhagam               40        40
# ...                                                   ...       ...
# Swabhimani Paksha                                       2         2
# Swaraj (J)                                              3         3
# Swarajya Party Of India                                 4         4
# Swatantra Samaj Party                                   1         1
# Tamil Nadu Makkal Congress                             10        10
# Telangana Communist Party of India                      1         1
# Telangana Loksatta Party                                2         2
# Telangana Rashtra Samithi                              17        17
# Telugu Desam                                           30        30
# The Lok Party of India                                  4         4
# The Religion of Man Revolving Political Party o...      1         1
# Thrinamool Tamil Nadu Congress                          1         1
# Tripura Pragatishil Gramin Congress                     2         2
# UTTARAKHAND PARIVARTAN PARTY                            1         1
# Ulzaipali Makkal Katchy                                 8         8
# Union Party of India                                    1         1
# United Communist Party of India                         3         3
# United Democratic Party                                 1         1
# Uttar Pradesh Republican Party                          1         1
# VANCHITSAMAJ INSAAF PARTY                               8         8
# Vanchit Jamat Party                                     1         1
# Vichara Jagruthi Congress Paksha                        1         1
# Viduthalai Chiruthaigal Katchi                          2         2
# Vishva Hindustani Sangathan                             3         3
# Vishva SHakti Party                                     1         1
# Voters Party                                            1         1
# Welfare Party Of India                                 25        25
# Yuva Sarkar                                             2         2
# Yuvajana Sramika Rythu Congress Party                  38        38
# awami aamjan party                                      2         2
#
#                                                     Candidate  Votes
# Party
# AARAKSHAN VIRODHI PARTY                                     3      3
# AJSU Party                                                 10     10
# Aadijan Mukti Sena                                          1      1
# Aadivasi Sena Party                                         2      2
# Aam Aadmi Party                                           432    432
# Aam Janata Party                                            1      1
# Aama Odisha Party                                           9      9
# Aazadi Ka Antim Aandolan Dal                                1      1
# Adarsh Manavtawadi Party                                    1      1
# Adarsh Rashtriya Vikas Party                                7      7
# Adarsh Samaj Party                                          1      1
# Agar Jan Party                                              2      2
# Akhand Bharat Samaj Party                                   1      1
# Akhil Bharat Hindu Mahasabha                                8      8
# Akhil Bharatiya Ashok Sena                                  1      1
# Akhil Bharatiya Congress Dal (Ambedkar)                     2      2
# Akhil Bharatiya Hind Kranti Party                           1      1
# Akhil Bharatiya Jan Sangh                                   4      4
# Akhil Bharatiya Manavata Paksha                             1      1
# Akhil Bharatiya Muslim League (Secular)                     5      5
# Akhil Bharatiya Rajarya Sabha                               1      1
# Akhil Bharatiya Samajwadi Congress                          1      1
# Akhil Bharatiya Shivsena Rashtrawadi                        1      1
# Akhil Bhartiya Aamjan Party                                 1      1
# Akhil Bhartiya Jharkhand Party                              3      3
# Akhil Bhartiya Mithila Party                                2      2
# Akhil Bhartiya Vikas Congress Party                         1      1
# Akhil Rashtrawadi Party                                     1      1
# Al-Hind Party                                               4      4
# All India Anna Dravida Munnetra Kazhagam                   40     40
# ...                                                       ...    ...
# Swabhimani Paksha                                           2      2
# Swaraj (J)                                                  3      3
# Swarajya Party Of India                                     4      4
# Swatantra Samaj Party                                       1      1
# Tamil Nadu Makkal Congress                                 10     10
# Telangana Communist Party of India                          1      1
# Telangana Loksatta Party                                    2      2
# Telangana Rashtra Samithi                                  17     17
# Telugu Desam                                               30     30
# The Lok Party of India                                      4      4
# The Religion of Man Revolving Political Party o...          1      1
# Thrinamool Tamil Nadu Congress                              1      1
# Tripura Pragatishil Gramin Congress                         2      2
# UTTARAKHAND PARIVARTAN PARTY                                1      1
# Ulzaipali Makkal Katchy                                     8      8
# Union Party of India                                        1      1
# United Communist Party of India                             3      3
# United Democratic Party                                     1      1
# Uttar Pradesh Republican Party                              1      1
# VANCHITSAMAJ INSAAF PARTY                                   8      8
# Vanchit Jamat Party                                         1      1
# Vichara Jagruthi Congress Paksha                            1      1
# Viduthalai Chiruthaigal Katchi                              2      2
# Vishva Hindustani Sangathan                                 3      3
# Vishva SHakti Party                                         1      1
# Voters Party                                                1      1
# Welfare Party Of India                                     25     25
# Yuva Sarkar                                                 2      2
# Yuvajana Sramika Rythu Congress Party                      38     38
# awami aamjan party                                          2      2
#
# [467 rows x 4 columns]

# %%
df2 = df.groupby(['Party']).count()
df2.plot(kind='line',figsize=(15,7))
plt.ylabel("no.of Assembly")
plt.xlabel("Party")
plt.show()

# %% [markdown]
# #### __What was the share of the independent candidates__?

# %%
df2.loc['Independent','Votes']
# Out:
# 3235

# %% [markdown]
# #### __Try to plot Scatter Plot of the Parameters you can__

# %%
plt.scatter(df1.Party,df1.Votes, c='green', alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('party')
plt.ylabel('votes')
plt.show()

# %%
plt.scatter(df2.State,df2.Votes, c='green', alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('state')
plt.ylabel('votes')
plt.show()

# %% [markdown]
# #### __Is three dimensional plot possible for any set of parameters in this dataset?__

# %%
no,It is not possible here.

# %% [markdown]
# #### __Try the wordplot of the BJP Seats in each state__
