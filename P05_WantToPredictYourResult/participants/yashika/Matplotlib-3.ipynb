# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
import pandas as pd
df = pd.read_excel('https://query.data.world/s/msbnsoqfh4vzsjnwqkd5n3zrcsuzct')

# %%
df.head() #It's messed up We can see clearly the 3rd index of row is actually the column name
# Out:
#   India General Elections 2014 - Complete list of candidate level votes sourced from election commission website eciresults.nic.in  \
# 0                                                NaN
# 1  Powered by Whizz WiFi - Social analytics and W...
# 2                                                NaN
# 3                                              State
# 4                          Andaman & Nicobar Islands
#
#                   Unnamed: 1       Unnamed: 2              Unnamed: 3  \
# 0                        NaN              NaN                     NaN
# 1                        NaN              NaN                     NaN
# 2                        NaN              NaN                     NaN
# 3                   Assembly        Candidate                   Party
# 4  Andaman & Nicobar Islands  BISHNU PADA RAY  Bharatiya Janata Party
#
#   Unnamed: 4
# 0        NaN
# 1        NaN
# 2        NaN
# 3      Votes
# 4      90969

# %%
df = df.rename(columns=df.iloc[3])
df.head()
# Out:
#                                                State  \
# 0                                                NaN
# 1  Powered by Whizz WiFi - Social analytics and W...
# 2                                                NaN
# 3                                              State
# 4                          Andaman & Nicobar Islands
#
#                     Assembly        Candidate                   Party  Votes
# 0                        NaN              NaN                     NaN    NaN
# 1                        NaN              NaN                     NaN    NaN
# 2                        NaN              NaN                     NaN    NaN
# 3                   Assembly        Candidate                   Party  Votes
# 4  Andaman & Nicobar Islands  BISHNU PADA RAY  Bharatiya Janata Party  90969

# %%
df = df.iloc[4:,:]
df.head()
# Out:
#                        State                   Assembly           Candidate  \
# 4  Andaman & Nicobar Islands  Andaman & Nicobar Islands     BISHNU PADA RAY
# 5  Andaman & Nicobar Islands  Andaman & Nicobar Islands  KULDEEP RAI SHARMA
# 6  Andaman & Nicobar Islands  Andaman & Nicobar Islands      SANJAY MESHACK
# 7  Andaman & Nicobar Islands  Andaman & Nicobar Islands        ANITA MONDAL
# 8  Andaman & Nicobar Islands  Andaman & Nicobar Islands             K.G.DAS
#
#                                 Party  Votes
# 4              Bharatiya Janata Party  90969
# 5            Indian National Congress  83157
# 6                     Aam Aadmi Party   3737
# 7        All India Trinamool Congress   2283
# 8  Communist Party of India (Marxist)   1777

# %% [markdown]
# ### Let's me explain this data to you:
#
# __State : This is state of our country which has many Assemblies__
#
# __Assembly: Smallest Piece where which election will happen.__
#
# __Candidate : Is the name of the candidate__
#
# __Party: This give insights to which party the person belongs to. (Independent if no party)__
#
# __Votes: It's not the total votes. IT'S THE MARGIN WITH WHICH THE WINNER WON__

# %% [markdown]
# #### Can you answer the following questions and as a prove provide visualizations for me?

# %% [markdown]
# #### __Which State has maximum Assembly?__

# %%
count=df.groupby(['State']).count()
count.head()
count.plot()

# %% [markdown]
# #### __Visualize the seat share of parties (Find the best way to present it)?__

# %%
df1=df.groupby(['Party']).count().Assembly
countAssem=df.Party.value_counts()
countAssem
plt.pie(countAssem)
# Out:
# ([<matplotlib.patches.Wedge at 0x27acc191080>], [Text(-1.1,1.34711e-16,'')])

# %% [markdown]
# #### __What was the share of the independent candidates__?

# %% [markdown]
# #### __Try to plot Scatter Plot of the Parameters you can__

# %%
plt.scatter(df['Party'],df['Votes'])

# %% [markdown]
# #### __Is three dimensional plot possible for any set of parameters in this dataset?__

# %% [markdown]
# #### __Try the wordplot of the BJP Seats in each state__

# %%
df.groupby('Party').count()
df['Party']='BJP'
df
# Out:
#                           State                   Assembly  \
# 4     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 5     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 6     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 7     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 9     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 10    Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 11    Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 12    Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 13    Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 14    Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 15    Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 16    Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 17    Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 18    Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 19    Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 20               Andhra Pradesh                   Adilabad
# 21               Andhra Pradesh                   Adilabad
# 22               Andhra Pradesh                   Adilabad
# 23               Andhra Pradesh                   Adilabad
# 24               Andhra Pradesh                   Adilabad
# 25               Andhra Pradesh                   Adilabad
# 26               Andhra Pradesh                   Adilabad
# 27               Andhra Pradesh                   Adilabad
# 28               Andhra Pradesh                   Adilabad
# 29               Andhra Pradesh                 Amalapuram
# 30               Andhra Pradesh                 Amalapuram
# 31               Andhra Pradesh                 Amalapuram
# 32               Andhra Pradesh                 Amalapuram
# 33               Andhra Pradesh                 Amalapuram
# ...                         ...                        ...
# 8769                West Bengal                  Srerampur
# 8770                West Bengal                  Srerampur
# 8771                West Bengal                  Srerampur
# 8772                West Bengal                  Srerampur
# 8773                West Bengal                     Tamluk
# 8774                West Bengal                     Tamluk
# 8775                West Bengal                     Tamluk
# 8776                West Bengal                     Tamluk
# 8777                West Bengal                     Tamluk
# 8778                West Bengal                     Tamluk
# 8779                West Bengal                     Tamluk
# 8780                West Bengal                     Tamluk
# 8781                West Bengal                     Tamluk
# 8782                West Bengal                     Tamluk
# 8783                West Bengal                     Tamluk
# 8784                West Bengal                   Uluberia
# 8785                West Bengal                   Uluberia
# 8786                West Bengal                   Uluberia
# 8787                West Bengal                   Uluberia
# 8788                West Bengal                   Uluberia
# 8789                West Bengal                   Uluberia
# 8790                West Bengal                   Uluberia
# 8791                West Bengal                   Uluberia
# 8792                West Bengal                   Uluberia
# 8793                West Bengal                   Uluberia
# 8794                West Bengal                   Uluberia
# 8795                West Bengal                   Uluberia
# 8796                West Bengal                   Uluberia
# 8797                West Bengal                   Uluberia
# 8798                        NaN                        NaN
#
#                                               Candidate Party      Votes
# 4                                       BISHNU PADA RAY   BJP      90969
# 5                                    KULDEEP RAI SHARMA   BJP      83157
# 6                                        SANJAY MESHACK   BJP       3737
# 7                                          ANITA MONDAL   BJP       2283
# 8                                               K.G.DAS   BJP       1777
# 9                                          PRAKASH MINJ   BJP       1587
# 10                                    R.S.UMA BHARATTHY   BJP       1151
# 11                                GOUR CHANDRA MAJUMDER   BJP       1139
# 12                                            SARAVANAN   BJP        847
# 13                                           N K P NAIR   BJP        436
# 14                                           V V KHALID   BJP        429
# 15                                       RAGHUBIR SINGH   BJP        379
# 16                                       C G SAJI KUMAR   BJP        334
# 17                                             N KANNAN   BJP        314
# 18                                            A PANDIAN   BJP        225
# 19                                    None of the Above   BJP       1564
# 20                                         GODAM NAGESH   BJP     430847
# 21                                               NARESH   BJP     259557
# 22                                        RAMESH RATHOD   BJP     184198
# 23                                      RATHOD SADASHIV   BJP      94420
# 24                                     NETHAWATH RAMDAS   BJP      41032
# 25                                     MOSALI CHINNAIAH   BJP       8859
# 26                                        PAWAR KRISHNA   BJP       5055
# 27                                        BANKA SAHADEV   BJP       4787
# 28                                    None of the Above   BJP      17084
# 29                             DR PANDULA RAVINDRA BABU   BJP     594547
# 30                                     PINIPE VISWARUPU   BJP     473971
# 31    AITHABATHULA JOGESWARA VENKATA BUTCHI MAHESWAR...   BJP      12182
# 32                                     G.V.HARSHA KUMAR   BJP       9931
# 33                                   GEDDAM SAMPADA RAO   BJP       7219
# ...                                                 ...   ...        ...
# 8769                                         MANASA SEN   BJP       3406
# 8770                                       MD. SHANAWAZ   BJP       2698
# 8771                                     KAILASH NASKAR   BJP       2674
# 8772                                  None of the Above   BJP      15374
# 8773                                   ADHIKARI SUVENDU   BJP     716928
# 8774                                   SEKH IBRAHIM ALI   BJP     470447
# 8775                                        BADSHA ALAM   BJP      86265
# 8776                                       ANWAR ALI SK   BJP      29645
# 8777                                    BIBEKANANDA RAY   BJP      10197
# 8778                               RAJYASHREE CHAUDHURI   BJP       3609
# 8779                                          KAMAL BAG   BJP       3110
# 8780                                    KALISANKAR JANA   BJP       2658
# 8781                                     ABDUR REZAK SK   BJP       1682
# 8782                               MANIK CHANDRA MONDAL   BJP       1500
# 8783                                  None of the Above   BJP      11643
# 8784                                       SULTAN AHMED   BJP     570785
# 8785                                  SABIR UDDIN MOLLA   BJP     369563
# 8786                             RANJIT KISHORE MOHANTY   BJP     137137
# 8787                                         ASIT MITRA   BJP      67826
# 8788                                         ABUL QASEM   BJP       6607
# 8789                                        HASAN NAWAJ   BJP       5709
# 8790                                   DILIP KUMAR HAIT   BJP       3947
# 8791                                          REKHA DAS   BJP       3918
# 8792                                SUSANTA KUMAR DALUI   BJP       2990
# 8793                                      MINATI SARKAR   BJP       2902
# 8794                                       RAMESH DHARA   BJP       2529
# 8795                                    ASHIS KUMAR DAS   BJP       2437
# 8796                                       SUJATA DUTTA   BJP       1400
# 8797                                  None of the Above   BJP       8277
# 8798                                                NaN   BJP  553801801
#
# [8795 rows x 5 columns]
