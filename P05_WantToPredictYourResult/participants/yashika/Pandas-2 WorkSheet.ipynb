# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("firstsem_cse.csv")

# %%
df.head()
# Out:
#            Student Name  EnrollMent No                SID  \
# 0              ABHISHEK      110102717  SID: 190000099690
# 1  ABHISHEK KUMAR VERMA      210102717  SID: 190000099691
# 2                ANJALI      510102717  SID: 190000099812
# 3        ANOOP PARASHAR      610102717  SID: 190000099813
# 4         ARSHWIN KUMAR      710102717  SID: 190000099814
#
#                 Scheme ID  AM-1 Internal  AM-1 External  AP-1 Internal  \
# 0  SchemeID: 190272015001             17             35             24
# 1  SchemeID: 190272015001             17             57             23
# 2  SchemeID: 190272015001             15             50             19
# 3  SchemeID: 190272015001              9             31             18
# 4  SchemeID: 190272015001             17             28             25
#
#    AP-1 External  MP Internal  MP External      ...        ET LAB External  \
# 0             50           25           30      ...                     53
# 1             64           22           47      ...                     48
# 2             59           17           38      ...                     40
# 3             31           20           46      ...                     40
# 4             42           22           49      ...                     48
#
#    MP LAB Internal  MP LAB External  FOC LAB Internal  FOC LAB External  \
# 0               36               40                36                45
# 1               38               45                36                47
# 2               35               43                31                47
# 3               36               46                36                45
# 4               38               35                31                45
#
#    ED LAB Internal  ED LAB External  AC LAB Internal  AC LAB External  \
# 0               30               45               37               56
# 1               34               55               39               58
# 2               27               36               35               53
# 3               32               37               29               46
# 4               30               32               33               50
#
#    Total Credits
# 0             27
# 1             27
# 2             27
# 3             27
# 4             27
#
# [5 rows x 30 columns]

# %% [markdown]
# ### __Set The Column Student Name as the Index__

# %%
df = pd.read_csv("firstsem_cse.csv",index_col="Student Name")
df.head()
# Out:
#                       EnrollMent No                SID  \
# Student Name
# ABHISHEK                  110102717  SID: 190000099690
# ABHISHEK KUMAR VERMA      210102717  SID: 190000099691
# ANJALI                    510102717  SID: 190000099812
# ANOOP PARASHAR            610102717  SID: 190000099813
# ARSHWIN KUMAR             710102717  SID: 190000099814
#
#                                    Scheme ID  AM-1 Internal  AM-1 External  \
# Student Name
# ABHISHEK              SchemeID: 190272015001             17             35
# ABHISHEK KUMAR VERMA  SchemeID: 190272015001             17             57
# ANJALI                SchemeID: 190272015001             15             50
# ANOOP PARASHAR        SchemeID: 190272015001              9             31
# ARSHWIN KUMAR         SchemeID: 190272015001             17             28
#
#                       AP-1 Internal  AP-1 External  MP Internal  MP External  \
# Student Name
# ABHISHEK                         24             50           25           30
# ABHISHEK KUMAR VERMA             23             64           22           47
# ANJALI                           19             59           17           38
# ANOOP PARASHAR                   18             31           20           46
# ARSHWIN KUMAR                    25             42           22           49
#
#                       ET Internal      ...        ET LAB External  \
# Student Name                           ...
# ABHISHEK                       22      ...                     53
# ABHISHEK KUMAR VERMA           17      ...                     48
# ANJALI                         15      ...                     40
# ANOOP PARASHAR                 13      ...                     40
# ARSHWIN KUMAR                  17      ...                     48
#
#                       MP LAB Internal  MP LAB External  FOC LAB Internal  \
# Student Name
# ABHISHEK                           36               40                36
# ABHISHEK KUMAR VERMA               38               45                36
# ANJALI                             35               43                31
# ANOOP PARASHAR                     36               46                36
# ARSHWIN KUMAR                      38               35                31
#
#                       FOC LAB External  ED LAB Internal  ED LAB External  \
# Student Name
# ABHISHEK                            45               30               45
# ABHISHEK KUMAR VERMA                47               34               55
# ANJALI                              47               27               36
# ANOOP PARASHAR                      45               32               37
# ARSHWIN KUMAR                       45               30               32
#
#                       AC LAB Internal  AC LAB External  Total Credits
# Student Name
# ABHISHEK                           37               56             27
# ABHISHEK KUMAR VERMA               39               58             27
# ANJALI                             35               53             27
# ANOOP PARASHAR                     29               46             27
# ARSHWIN KUMAR                      33               50             27
#
# [5 rows x 29 columns]

# %% [markdown]
# ### __Drop the Enrollment No, Columns SID,Scheme ID, ALL LAB SUBJECTS (LAB IN THEIR NAME) and Total Credits from the DataFrame df__
# Don't make new dataset save it to df as we have to do more operations that is dependent over it(If stuck better ask in the group)

# %%
df=df.drop(['SID','EnrollMent No','Scheme ID','Total Credits'],axis=1)
df.head(4)
# Out:
#                       AM-1 Internal  AM-1 External  AP-1 Internal  \
# Student Name
# ABHISHEK                         17             35             24
# ABHISHEK KUMAR VERMA             17             57             23
# ANJALI                           15             50             19
# ANOOP PARASHAR                    9             31             18
#
#                       AP-1 External  MP Internal  MP External  ET Internal  \
# Student Name
# ABHISHEK                         50           25           30           22
# ABHISHEK KUMAR VERMA             64           22           47           17
# ANJALI                           59           17           38           15
# ANOOP PARASHAR                   31           20           46           13
#
#                       ET External  HVPE External  FOC Internal  \
# Student Name
# ABHISHEK                       36             90            19
# ABHISHEK KUMAR VERMA           57             89            19
# ANJALI                         54             82            16
# ANOOP PARASHAR                 42             76            19
#
#                            ...         ET LAB Internal  ET LAB External  \
# Student Name               ...
# ABHISHEK                   ...                      35               53
# ABHISHEK KUMAR VERMA       ...                      33               48
# ANJALI                     ...                      26               40
# ANOOP PARASHAR             ...                      23               40
#
#                       MP LAB Internal  MP LAB External  FOC LAB Internal  \
# Student Name
# ABHISHEK                           36               40                36
# ABHISHEK KUMAR VERMA               38               45                36
# ANJALI                             35               43                31
# ANOOP PARASHAR                     36               46                36
#
#                       FOC LAB External  ED LAB Internal  ED LAB External  \
# Student Name
# ABHISHEK                            45               30               45
# ABHISHEK KUMAR VERMA                47               34               55
# ANJALI                              47               27               36
# ANOOP PARASHAR                      45               32               37
#
#                       AC LAB Internal  AC LAB External
# Student Name
# ABHISHEK                           37               56
# ABHISHEK KUMAR VERMA               39               58
# ANJALI                             35               53
# ANOOP PARASHAR                     29               46
#
# [4 rows x 25 columns]

# %%
delete=[]
for i in df.columns:
    if "LAB" in i:
        delete.append(i)
delete
# Out:
# ['AP-1 LAB Internal',
#  'AP-1 LAB External',
#  'ET LAB Internal',
#  'ET LAB External',
#  'MP LAB Internal',
#  'MP LAB External',
#  'FOC LAB Internal',
#  'FOC LAB External',
#  'ED LAB Internal',
#  'ED LAB External',
#  'AC LAB Internal',
#  'AC LAB External']

# %%
df=df.drop(delete,axis=1)
df.head()
# Out:
#                       AM-1 Internal  AM-1 External  AP-1 Internal  \
# Student Name
# ABHISHEK                         17             35             24
# ABHISHEK KUMAR VERMA             17             57             23
# ANJALI                           15             50             19
# ANOOP PARASHAR                    9             31             18
# ARSHWIN KUMAR                    17             28             25
#
#                       AP-1 External  MP Internal  MP External  ET Internal  \
# Student Name
# ABHISHEK                         50           25           30           22
# ABHISHEK KUMAR VERMA             64           22           47           17
# ANJALI                           59           17           38           15
# ANOOP PARASHAR                   31           20           46           13
# ARSHWIN KUMAR                    42           22           49           17
#
#                       ET External  HVPE External  FOC Internal  FOC External  \
# Student Name
# ABHISHEK                       36             90            19            51
# ABHISHEK KUMAR VERMA           57             89            19            65
# ANJALI                         54             82            16            52
# ANOOP PARASHAR                 42             76            19            45
# ARSHWIN KUMAR                  54             85            16            59
#
#                       AC Internal  AC External
# Student Name
# ABHISHEK                       23           50
# ABHISHEK KUMAR VERMA           24           63
# ANJALI                         17           52
# ANOOP PARASHAR                 14           30
# ARSHWIN KUMAR                  24           34

# %% [markdown]
# ### __Add a Column Name Total Marks which will have total marks of each row (Summation of all marks obtained)__

# %%
df['Total Marks']=df.sum(axis=1)
df.head()
# Out:
#                       AM-1 Internal  AM-1 External  AP-1 Internal  \
# Student Name
# ABHISHEK                         17             35             24
# ABHISHEK KUMAR VERMA             17             57             23
# ANJALI                           15             50             19
# ANOOP PARASHAR                    9             31             18
# ARSHWIN KUMAR                    17             28             25
#
#                       AP-1 External  MP Internal  MP External  ET Internal  \
# Student Name
# ABHISHEK                         50           25           30           22
# ABHISHEK KUMAR VERMA             64           22           47           17
# ANJALI                           59           17           38           15
# ANOOP PARASHAR                   31           20           46           13
# ARSHWIN KUMAR                    42           22           49           17
#
#                       ET External  HVPE External  FOC Internal  FOC External  \
# Student Name
# ABHISHEK                       36             90            19            51
# ABHISHEK KUMAR VERMA           57             89            19            65
# ANJALI                         54             82            16            52
# ANOOP PARASHAR                 42             76            19            45
# ARSHWIN KUMAR                  54             85            16            59
#
#                       AC Internal  AC External  Total Marks
# Student Name
# ABHISHEK                       23           50          472
# ABHISHEK KUMAR VERMA           24           63          564
# ANJALI                         17           52          486
# ANOOP PARASHAR                 14           30          394
# ARSHWIN KUMAR                  24           34          472

# %% [markdown]
# ### __Combine all the columns__
# * Combine Columns of External and Internal Marks into one i.e AM-1 Internal and AM-1 External must be added and stored to another column named AM-1 Total(drop the AM-1 Internal and AM-1 External After that). Use any of the technique you like and do the same for all the subjects.
#
# ** __ATTENTION__ **
# * A subject named HVPE doesn't have internal marks.
#
#
# __Dataframe after this step must look like__
#
# | Student Name |AM-1 Total|AM-1 Total|AP-1 Total|MP Total|ET Total|HVPE Total| FOC Total|AC Total|Total Marks|
# |------|------|------|------|------|------|------|------|------|--|

# %%
df=df.drop('HVPE External',axis=1)
internal=[]
for i in df.columns:
    if "Internal" in i:
        internal.append(i)
external=[]
for i in df.columns:
    if "External" in i:
        external.append(i)
combine=[]
for x,y in zip((internal),(external)):
    combine.extend([x,y])
combine
# Out:
# ['AM-1 Internal',
#  'AM-1 External',
#  'AP-1 Internal',
#  'AP-1 External',
#  'MP Internal',
#  'MP External',
#  'ET Internal',
#  'ET External',
#  'FOC Internal',
#  'FOC External',
#  'AC Internal',
#  'AC External']

# %%
l=['AM-1 Total',
'AM-1 Total'
,'AP-1 Total'
,'MP Total'
,'ET Total'
,'FOC Total'
,'AC Total']
for i,j in zip(range(0,len(combine),2),range(len(l))):
    df[l[j]]=df[combine[i]]+df[combine[i+1]]

# %%
df=df.drop(combine,axis=1)
df.head()
# Out:
#                       Total Marks  AM-1 Total  AP-1 Total  MP Total  ET Total  \
# Student Name
# ABHISHEK                      472          74          55        58        70
# ABHISHEK KUMAR VERMA          564          87          69        74        84
# ANJALI                        486          78          55        69        68
# ANOOP PARASHAR                394          49          66        55        64
# ARSHWIN KUMAR                 472          67          71        71        75
#
#                       FOC Total
# Student Name
# ABHISHEK                     73
# ABHISHEK KUMAR VERMA         87
# ANJALI                       69
# ANOOP PARASHAR               44
# ARSHWIN KUMAR                58

# %%
#Removed HVPE as it had only one score out of internal and external

# %% [markdown]
# ### __Find Mean Marks of All the subjects.__

# %%
df.mean()
# Out:
# Total Marks    444.336358
# AM-1 Total      60.275862
# AP-1 Total      62.153660
# MP Total        58.385360
# ET Total        64.421658
# FOC Total       63.170599
# dtype: float64

# %% [markdown]
# ### __Find Variance and Standard Deviation for each Subject and tell me what does it mean?__

# %%
variance=df.var()
sd=df.std()

# %%
print(variance,sd)
# Out:
# Total Marks    5815.464277
# AM-1 Total      227.892377
# AP-1 Total      208.844413
# MP Total        204.193418
# ET Total        124.297279
# FOC Total       214.032622
# dtype: float64 Total Marks    76.259191
# AM-1 Total     15.096105
# AP-1 Total     14.451450
# MP Total       14.289626
# ET Total       11.148869
# FOC Total      14.629854
# dtype: float64
