# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_excel('https://query.data.world/s/msbnsoqfh4vzsjnwqkd5n3zrcsuzct',index_col=None)

# %%
df.head() #It's messed up We can see clearly the 3rd index of row is actually the column name
# Out:
#   India General Elections 2014 - Complete list of candidate level votes sourced from election commission website eciresults.nic.in  \
# 0                                                NaN
# 1  Powered by Whizz WiFi - Social analytics and W...
# 2                                                NaN
# 3                                              State
# 4                          Andaman & Nicobar Islands
#
#                   Unnamed: 1       Unnamed: 2              Unnamed: 3  \
# 0                        NaN              NaN                     NaN
# 1                        NaN              NaN                     NaN
# 2                        NaN              NaN                     NaN
# 3                   Assembly        Candidate                   Party
# 4  Andaman & Nicobar Islands  BISHNU PADA RAY  Bharatiya Janata Party
#
#   Unnamed: 4
# 0        NaN
# 1        NaN
# 2        NaN
# 3      Votes
# 4      90969

# %%
df = df.rename(columns=df.iloc[3])
df.head()
# Out:
#                                                State  \
# 0                                                NaN
# 1  Powered by Whizz WiFi - Social analytics and W...
# 2                                                NaN
# 3                                              State
# 4                          Andaman & Nicobar Islands
#
#                     Assembly        Candidate                   Party  Votes
# 0                        NaN              NaN                     NaN    NaN
# 1                        NaN              NaN                     NaN    NaN
# 2                        NaN              NaN                     NaN    NaN
# 3                   Assembly        Candidate                   Party  Votes
# 4  Andaman & Nicobar Islands  BISHNU PADA RAY  Bharatiya Janata Party  90969

# %%
df = df.iloc[4:,:]
df.head()
# Out:
#                         State                   Assembly  \
# 8   Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 9   Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 10  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 11  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 12  Andaman & Nicobar Islands  Andaman & Nicobar Islands
#
#                 Candidate                               Party Votes
# 8                 K.G.DAS  Communist Party of India (Marxist)  1777
# 9            PRAKASH MINJ                         Independent  1587
# 10      R.S.UMA BHARATTHY          Nationalist Congress Party  1151
# 11  GOUR CHANDRA MAJUMDER                 Bahujan Samaj Party  1139
# 12              SARAVANAN                         Independent   847

# %% [markdown]
# ### Let's me explain this data to you:
#
# __State : This is state of our country which has many Assemblies__
#
# __Assembly: Smallest Piece where which election will happen.__
#
# __Candidate : Is the name of the candidate__
#
# __Party: This give insights to which party the person belongs to. (Independent if no party)__
#
# __Votes: It's not the total votes. IT'S THE MARGIN WITH WHICH THE WINNER WON__

# %% [markdown]
# #### Can you answer the following questions and as a prove provide visualizations for me?

# %% [markdown]
# #### __Which State has maximum Assembly?__

# %%
df2=df.groupby('Party').count()
df2.head()
# Out:
#                          State  Assembly  Candidate  Votes
# Party
# AARAKSHAN VIRODHI PARTY      3         3          3      3
# AJSU Party                  10        10         10     10
# Aadijan Mukti Sena           1         1          1      1
# Aadivasi Sena Party          2         2          2      2
# Aam Aadmi Party            431       431        431    431

# %%
df1=df.groupby(['State']).count()
df1.plot(kind='line')
plt.show()

# %% [markdown]
# #### __Visualize the seat share of parties (Find the best way to present it)?__

# %%
#df2=df.groupby('Party').count().Assembly
df2=df.Party.value_counts()
df2.head()
# Out:
# Independent                 3235
# None of the Above            543
# Bahujan Samaj Party          503
# Indian National Congress     463
# Aam Aadmi Party              431
# Name: Party, dtype: int64

# %%
plt.pie(df2, labels) #how to set Party name here as label?
# Out:
# ([<matplotlib.patches.Wedge at 0x1f93c252240>,
#   <matplotlib.patches.Wedge at 0x1f93c252780>,
#   <matplotlib.patches.Wedge at 0x1f93c252c50>,
#   <matplotlib.patches.Wedge at 0x1f93c25f278>,
#   <matplotlib.patches.Wedge at 0x1f93c25f748>,
#   <matplotlib.patches.Wedge at 0x1f93c25fb38>,
#   <matplotlib.patches.Wedge at 0x1f93c36b048>,
#   <matplotlib.patches.Wedge at 0x1f93c36b518>,
#   <matplotlib.patches.Wedge at 0x1f93c36b9e8>,
#   <matplotlib.patches.Wedge at 0x1f93c36beb8>,
#   <matplotlib.patches.Wedge at 0x1f93c2d93c8>,
#   <matplotlib.patches.Wedge at 0x1f93c36e860>,
#   <matplotlib.patches.Wedge at 0x1f93c36ed30>,
#   <matplotlib.patches.Wedge at 0x1f93c382240>,
#   <matplotlib.patches.Wedge at 0x1f93c382710>,
#   <matplotlib.patches.Wedge at 0x1f93c382be0>,
#   <matplotlib.patches.Wedge at 0x1f93c38e0f0>,
#   <matplotlib.patches.Wedge at 0x1f93c38e5c0>,
#   <matplotlib.patches.Wedge at 0x1f93c38ea90>,
#   <matplotlib.patches.Wedge at 0x1f93c38ef60>,
#   <matplotlib.patches.Wedge at 0x1f93c399470>,
#   <matplotlib.patches.Wedge at 0x1f93c399940>,
#   <matplotlib.patches.Wedge at 0x1f93c399e10>,
#   <matplotlib.patches.Wedge at 0x1f93c2e3320>,
#   <matplotlib.patches.Wedge at 0x1f93c2e37f0>,
#   <matplotlib.patches.Wedge at 0x1f93c2e3cc0>,
#   <matplotlib.patches.Wedge at 0x1f93c2ee1d0>,
#   <matplotlib.patches.Wedge at 0x1f93c2ee6a0>,
#   <matplotlib.patches.Wedge at 0x1f93c2eeb70>,
#   <matplotlib.patches.Wedge at 0x1f93c2f9080>,
#   <matplotlib.patches.Wedge at 0x1f93c2f9550>,
#   <matplotlib.patches.Wedge at 0x1f93c2f9a20>,
#   <matplotlib.patches.Wedge at 0x1f93c2f9ef0>,
#   <matplotlib.patches.Wedge at 0x1f93c300400>,
#   <matplotlib.patches.Wedge at 0x1f93c3008d0>,
#   <matplotlib.patches.Wedge at 0x1f93c300da0>,
#   <matplotlib.patches.Wedge at 0x1f93c30b2b0>,
#   <matplotlib.patches.Wedge at 0x1f93c30b780>,
#   <matplotlib.patches.Wedge at 0x1f93c30bc50>,
#   <matplotlib.patches.Wedge at 0x1f93c314160>,
#   <matplotlib.patches.Wedge at 0x1f93c314630>,
#   <matplotlib.patches.Wedge at 0x1f93c314b00>,
#   <matplotlib.patches.Wedge at 0x1f93c314fd0>,
#   <matplotlib.patches.Wedge at 0x1f93c2c44e0>,
#   <matplotlib.patches.Wedge at 0x1f93c2c49b0>,
#   <matplotlib.patches.Wedge at 0x1f93c2c4e80>,
#   <matplotlib.patches.Wedge at 0x1f93c2c5390>,
#   <matplotlib.patches.Wedge at 0x1f93c2c5860>,
#   <matplotlib.patches.Wedge at 0x1f93c2c5d30>,
#   <matplotlib.patches.Wedge at 0x1f93c2db240>,
#   <matplotlib.patches.Wedge at 0x1f93c2db710>,
#   <matplotlib.patches.Wedge at 0x1f93c2dbbe0>,
#   <matplotlib.patches.Wedge at 0x1f93c2ba0f0>,
#   <matplotlib.patches.Wedge at 0x1f93c2ba5c0>,
#   <matplotlib.patches.Wedge at 0x1f93c2baa90>,
#   <matplotlib.patches.Wedge at 0x1f93c2baf60>,
#   <matplotlib.patches.Wedge at 0x1f93c2ab470>,
#   <matplotlib.patches.Wedge at 0x1f93c2ab940>,
#   <matplotlib.patches.Wedge at 0x1f93c2abe10>,
#   <matplotlib.patches.Wedge at 0x1f93c2b7320>,
#   <matplotlib.patches.Wedge at 0x1f93c2b77f0>,
#   <matplotlib.patches.Wedge at 0x1f93c2b7cc0>,
#   <matplotlib.patches.Wedge at 0x1f93c2621d0>,
#   <matplotlib.patches.Wedge at 0x1f93c2626a0>,
#   <matplotlib.patches.Wedge at 0x1f93c262b70>,
#   <matplotlib.patches.Wedge at 0x1f93c26b080>,
#   <matplotlib.patches.Wedge at 0x1f93c26b550>,
#   <matplotlib.patches.Wedge at 0x1f93c26ba20>,
#   <matplotlib.patches.Wedge at 0x1f93c26bef0>,
#   <matplotlib.patches.Wedge at 0x1f93c274400>,
#   <matplotlib.patches.Wedge at 0x1f93c2748d0>,
#   <matplotlib.patches.Wedge at 0x1f93c274da0>,
#   <matplotlib.patches.Wedge at 0x1f93c27d2b0>,
#   <matplotlib.patches.Wedge at 0x1f93c27d780>,
#   <matplotlib.patches.Wedge at 0x1f93c27dc50>,
#   <matplotlib.patches.Wedge at 0x1f93c28b160>,
#   <matplotlib.patches.Wedge at 0x1f93c28b630>,
#   <matplotlib.patches.Wedge at 0x1f93c28bb00>,
#   <matplotlib.patches.Wedge at 0x1f93c28bfd0>,
#   <matplotlib.patches.Wedge at 0x1f93c2944e0>,
#   <matplotlib.patches.Wedge at 0x1f93c2949b0>,
#   <matplotlib.patches.Wedge at 0x1f93c294e80>,
#   <matplotlib.patches.Wedge at 0x1f93c29a390>,
#   <matplotlib.patches.Wedge at 0x1f93c29a860>,
#   <matplotlib.patches.Wedge at 0x1f93c29ad30>,
#   <matplotlib.patches.Wedge at 0x1f93c325240>,
#   <matplotlib.patches.Wedge at 0x1f93c325710>,
#   <matplotlib.patches.Wedge at 0x1f93c325be0>,
#   <matplotlib.patches.Wedge at 0x1f93c32e0f0>,
#   <matplotlib.patches.Wedge at 0x1f93c32e5c0>,
#   <matplotlib.patches.Wedge at 0x1f93c32ea90>,
#   <matplotlib.patches.Wedge at 0x1f93c32ef60>,
#   <matplotlib.patches.Wedge at 0x1f93c339470>,
#   <matplotlib.patches.Wedge at 0x1f93c339940>,
#   <matplotlib.patches.Wedge at 0x1f93c339e10>,
#   <matplotlib.patches.Wedge at 0x1f93c342320>,
#   <matplotlib.patches.Wedge at 0x1f93c3427f0>,
#   <matplotlib.patches.Wedge at 0x1f93c342cc0>,
#   <matplotlib.patches.Wedge at 0x1f93c34d1d0>,
#   <matplotlib.patches.Wedge at 0x1f93c34d6a0>,
#   <matplotlib.patches.Wedge at 0x1f93c34db70>,
#   <matplotlib.patches.Wedge at 0x1f93c356080>,
#   <matplotlib.patches.Wedge at 0x1f93c356550>,
#   <matplotlib.patches.Wedge at 0x1f93c356a20>,
#   <matplotlib.patches.Wedge at 0x1f93c356ef0>,
#   <matplotlib.patches.Wedge at 0x1f93c3a0400>,
#   <matplotlib.patches.Wedge at 0x1f93c3a08d0>,
#   <matplotlib.patches.Wedge at 0x1f93c3a0da0>,
#   <matplotlib.patches.Wedge at 0x1f93c3a92b0>,
#   <matplotlib.patches.Wedge at 0x1f93c3a9780>,
#   <matplotlib.patches.Wedge at 0x1f93c3a9c50>,
#   <matplotlib.patches.Wedge at 0x1f93c3b2160>,
#   <matplotlib.patches.Wedge at 0x1f93c3b2630>,
#   <matplotlib.patches.Wedge at 0x1f93c3b2b00>,
#   <matplotlib.patches.Wedge at 0x1f93c3b2fd0>,
#   <matplotlib.patches.Wedge at 0x1f93c3bd4e0>,
#   <matplotlib.patches.Wedge at 0x1f93c3bd9b0>,
#   <matplotlib.patches.Wedge at 0x1f93c3bde80>,
#   <matplotlib.patches.Wedge at 0x1f93c3c5390>,
#   <matplotlib.patches.Wedge at 0x1f93c3c5860>,
#   <matplotlib.patches.Wedge at 0x1f93c3c5d30>,
#   <matplotlib.patches.Wedge at 0x1f93c3d0240>,
#   <matplotlib.patches.Wedge at 0x1f93c3d0710>,
#   <matplotlib.patches.Wedge at 0x1f93c3d0be0>,
#   <matplotlib.patches.Wedge at 0x1f93c3d90f0>,
#   <matplotlib.patches.Wedge at 0x1f93c3d95c0>,
#   <matplotlib.patches.Wedge at 0x1f93c3d9a90>,
#   <matplotlib.patches.Wedge at 0x1f93c3d9f60>,
#   <matplotlib.patches.Wedge at 0x1f93c3e4470>,
#   <matplotlib.patches.Wedge at 0x1f93c3e4940>,
#   <matplotlib.patches.Wedge at 0x1f93c3e4e10>,
#   <matplotlib.patches.Wedge at 0x1f93c3ed320>,
#   <matplotlib.patches.Wedge at 0x1f93c3ed7f0>,
#   <matplotlib.patches.Wedge at 0x1f93c3edcc0>,
#   <matplotlib.patches.Wedge at 0x1f93c3f61d0>,
#   <matplotlib.patches.Wedge at 0x1f93c3f66a0>,
#   <matplotlib.patches.Wedge at 0x1f93c3f6b70>,
#   <matplotlib.patches.Wedge at 0x1f93c3ff080>,
#   <matplotlib.patches.Wedge at 0x1f93c3ff550>,
#   <matplotlib.patches.Wedge at 0x1f93c3ffa20>,
#   <matplotlib.patches.Wedge at 0x1f93c3ffef0>,
#   <matplotlib.patches.Wedge at 0x1f93c40b400>,
#   <matplotlib.patches.Wedge at 0x1f93c40b8d0>,
#   <matplotlib.patches.Wedge at 0x1f93c40bda0>,
#   <matplotlib.patches.Wedge at 0x1f93c4132b0>,
#   <matplotlib.patches.Wedge at 0x1f93c413780>,
#   <matplotlib.patches.Wedge at 0x1f93c413c50>,
#   <matplotlib.patches.Wedge at 0x1f93c41d160>,
#   <matplotlib.patches.Wedge at 0x1f93c41d630>,
#   <matplotlib.patches.Wedge at 0x1f93c41db00>,
#   <matplotlib.patches.Wedge at 0x1f93c41dfd0>,
#   <matplotlib.patches.Wedge at 0x1f93c4274e0>,
#   <matplotlib.patches.Wedge at 0x1f93c4279b0>,
#   <matplotlib.patches.Wedge at 0x1f93c427e80>,
#   <matplotlib.patches.Wedge at 0x1f93c431390>,
#   <matplotlib.patches.Wedge at 0x1f93c431860>,
#   <matplotlib.patches.Wedge at 0x1f93c431d30>,
#   <matplotlib.patches.Wedge at 0x1f93c43b240>,
#   <matplotlib.patches.Wedge at 0x1f93c43b710>,
#   <matplotlib.patches.Wedge at 0x1f93c43bbe0>,
#   <matplotlib.patches.Wedge at 0x1f93c4420f0>,
#   <matplotlib.patches.Wedge at 0x1f93c4425c0>,
#   <matplotlib.patches.Wedge at 0x1f93c442a90>,
#   <matplotlib.patches.Wedge at 0x1f93c442f60>,
#   <matplotlib.patches.Wedge at 0x1f93c44e470>,
#   <matplotlib.patches.Wedge at 0x1f93c44e940>,
#   <matplotlib.patches.Wedge at 0x1f93c44ee10>,
#   <matplotlib.patches.Wedge at 0x1f93c457320>,
#   <matplotlib.patches.Wedge at 0x1f93c4577f0>,
#   <matplotlib.patches.Wedge at 0x1f93c457cc0>,
#   <matplotlib.patches.Wedge at 0x1f93c4621d0>,
#   <matplotlib.patches.Wedge at 0x1f93c4626a0>,
#   <matplotlib.patches.Wedge at 0x1f93c462b70>,
#   <matplotlib.patches.Wedge at 0x1f93c46b080>,
#   <matplotlib.patches.Wedge at 0x1f93c46b550>,
#   <matplotlib.patches.Wedge at 0x1f93c46ba20>,
#   <matplotlib.patches.Wedge at 0x1f93c46bef0>,
#   <matplotlib.patches.Wedge at 0x1f93c476400>,
#   <matplotlib.patches.Wedge at 0x1f93c4768d0>,
#   <matplotlib.patches.Wedge at 0x1f93c476da0>,
#   <matplotlib.patches.Wedge at 0x1f93c47f2b0>,
#   <matplotlib.patches.Wedge at 0x1f93c47f780>,
#   <matplotlib.patches.Wedge at 0x1f93c47fc50>,
#   <matplotlib.patches.Wedge at 0x1f93c489160>,
#   <matplotlib.patches.Wedge at 0x1f93c489630>,
#   <matplotlib.patches.Wedge at 0x1f93c489b00>,
#   <matplotlib.patches.Wedge at 0x1f93c489fd0>,
#   <matplotlib.patches.Wedge at 0x1f93c4924e0>,
#   <matplotlib.patches.Wedge at 0x1f93c4929b0>,
#   <matplotlib.patches.Wedge at 0x1f93c492e80>,
#   <matplotlib.patches.Wedge at 0x1f93c49b390>,
#   <matplotlib.patches.Wedge at 0x1f93c49b860>,
#   <matplotlib.patches.Wedge at 0x1f93c49bd30>,
#   <matplotlib.patches.Wedge at 0x1f93c4a7240>,
#   <matplotlib.patches.Wedge at 0x1f93c4a7710>,
#   <matplotlib.patches.Wedge at 0x1f93c4a7be0>,
#   <matplotlib.patches.Wedge at 0x1f93c4af0f0>,
#   <matplotlib.patches.Wedge at 0x1f93c4af5c0>,
#   <matplotlib.patches.Wedge at 0x1f93c4afa90>,
#   <matplotlib.patches.Wedge at 0x1f93c4aff60>,
#   <matplotlib.patches.Wedge at 0x1f93c4ba470>,
#   <matplotlib.patches.Wedge at 0x1f93c4ba940>,
#   <matplotlib.patches.Wedge at 0x1f93c4bae10>,
#   <matplotlib.patches.Wedge at 0x1f93c4c3320>,
#   <matplotlib.patches.Wedge at 0x1f93c4c37f0>,
#   <matplotlib.patches.Wedge at 0x1f93c4c3cc0>,
#   <matplotlib.patches.Wedge at 0x1f93c4ce1d0>,
#   <matplotlib.patches.Wedge at 0x1f93c4ce6a0>,
#   <matplotlib.patches.Wedge at 0x1f93c4ceb70>,
#   <matplotlib.patches.Wedge at 0x1f93c4d7080>,
#   <matplotlib.patches.Wedge at 0x1f93c4d7550>,
#   <matplotlib.patches.Wedge at 0x1f93c4d7a20>,
#   <matplotlib.patches.Wedge at 0x1f93c4d7ef0>,
#   <matplotlib.patches.Wedge at 0x1f93c4df400>,
#   <matplotlib.patches.Wedge at 0x1f93c4df8d0>,
#   <matplotlib.patches.Wedge at 0x1f93c4dfda0>,
#   <matplotlib.patches.Wedge at 0x1f93c4eb2b0>,
#   <matplotlib.patches.Wedge at 0x1f93c4eb780>,
#   <matplotlib.patches.Wedge at 0x1f93c4ebc50>,
#   <matplotlib.patches.Wedge at 0x1f93c4f4160>,
#   <matplotlib.patches.Wedge at 0x1f93c4f4630>,
#   <matplotlib.patches.Wedge at 0x1f93c4f4b00>,
#   <matplotlib.patches.Wedge at 0x1f93c4f4fd0>,
#   <matplotlib.patches.Wedge at 0x1f93c4fd4e0>,
#   <matplotlib.patches.Wedge at 0x1f93c4fd9b0>,
#   <matplotlib.patches.Wedge at 0x1f93c4fde80>,
#   <matplotlib.patches.Wedge at 0x1f93c508390>,
#   <matplotlib.patches.Wedge at 0x1f93c508860>,
#   <matplotlib.patches.Wedge at 0x1f93c508d30>,
#   <matplotlib.patches.Wedge at 0x1f93c511240>,
#   <matplotlib.patches.Wedge at 0x1f93c511710>,
#   <matplotlib.patches.Wedge at 0x1f93c511be0>,
#   <matplotlib.patches.Wedge at 0x1f93c51b0f0>,
#   <matplotlib.patches.Wedge at 0x1f93c51b5c0>,
#   <matplotlib.patches.Wedge at 0x1f93c51ba90>,
#   <matplotlib.patches.Wedge at 0x1f93c51bf60>,
#   <matplotlib.patches.Wedge at 0x1f93c525470>,
#   <matplotlib.patches.Wedge at 0x1f93c525940>,
#   <matplotlib.patches.Wedge at 0x1f93c525e10>,
#   <matplotlib.patches.Wedge at 0x1f93c52e320>,
#   <matplotlib.patches.Wedge at 0x1f93c52e7f0>,
#   <matplotlib.patches.Wedge at 0x1f93c52ecc0>,
#   <matplotlib.patches.Wedge at 0x1f93c5391d0>,
#   <matplotlib.patches.Wedge at 0x1f93c5396a0>,
#   <matplotlib.patches.Wedge at 0x1f93c539b70>,
#   <matplotlib.patches.Wedge at 0x1f93c542080>,
#   <matplotlib.patches.Wedge at 0x1f93c542550>,
#   <matplotlib.patches.Wedge at 0x1f93c542a20>,
#   <matplotlib.patches.Wedge at 0x1f93c542ef0>,
#   <matplotlib.patches.Wedge at 0x1f93c54d400>,
#   <matplotlib.patches.Wedge at 0x1f93c54d8d0>,
#   <matplotlib.patches.Wedge at 0x1f93c54dda0>,
#   <matplotlib.patches.Wedge at 0x1f93c5552b0>,
#   <matplotlib.patches.Wedge at 0x1f93c555780>,
#   <matplotlib.patches.Wedge at 0x1f93c555c50>,
#   <matplotlib.patches.Wedge at 0x1f93c560160>,
#   <matplotlib.patches.Wedge at 0x1f93c560630>,
#   <matplotlib.patches.Wedge at 0x1f93c560b00>,
#   <matplotlib.patches.Wedge at 0x1f93c560fd0>,
#   <matplotlib.patches.Wedge at 0x1f93c56a4e0>,
#   <matplotlib.patches.Wedge at 0x1f93c56a9b0>,
#   <matplotlib.patches.Wedge at 0x1f93c56ae80>,
#   <matplotlib.patches.Wedge at 0x1f93c572390>,
#   <matplotlib.patches.Wedge at 0x1f93c572860>,
#   <matplotlib.patches.Wedge at 0x1f93c572d30>,
#   <matplotlib.patches.Wedge at 0x1f93c57d240>,
#   <matplotlib.patches.Wedge at 0x1f93c57d710>,
#   <matplotlib.patches.Wedge at 0x1f93c57dbe0>,
#   <matplotlib.patches.Wedge at 0x1f93c5860f0>,
#   <matplotlib.patches.Wedge at 0x1f93c5865c0>,
#   <matplotlib.patches.Wedge at 0x1f93c586a90>,
#   <matplotlib.patches.Wedge at 0x1f93c586f60>,
#   <matplotlib.patches.Wedge at 0x1f93c591470>,
#   <matplotlib.patches.Wedge at 0x1f93c591940>,
#   <matplotlib.patches.Wedge at 0x1f93c591e10>,
#   <matplotlib.patches.Wedge at 0x1f93c59a320>,
#   <matplotlib.patches.Wedge at 0x1f93c59a7f0>,
#   <matplotlib.patches.Wedge at 0x1f93c59acc0>,
#   <matplotlib.patches.Wedge at 0x1f93c5a41d0>,
#   <matplotlib.patches.Wedge at 0x1f93c5a46a0>,
#   <matplotlib.patches.Wedge at 0x1f93c5a4b70>,
#   <matplotlib.patches.Wedge at 0x1f93c5ad080>,
#   <matplotlib.patches.Wedge at 0x1f93c5ad550>,
#   <matplotlib.patches.Wedge at 0x1f93c5ada20>,
#   <matplotlib.patches.Wedge at 0x1f93c5adef0>,
#   <matplotlib.patches.Wedge at 0x1f93c5b7400>,
#   <matplotlib.patches.Wedge at 0x1f93c5b78d0>,
#   <matplotlib.patches.Wedge at 0x1f93c5b7da0>,
#   <matplotlib.patches.Wedge at 0x1f93c5c22b0>,
#   <matplotlib.patches.Wedge at 0x1f93c5c2780>,
#   <matplotlib.patches.Wedge at 0x1f93c5c2c50>,
#   <matplotlib.patches.Wedge at 0x1f93c5cb160>,
#   <matplotlib.patches.Wedge at 0x1f93c5cb630>,
#   <matplotlib.patches.Wedge at 0x1f93c5cbb00>,
#   <matplotlib.patches.Wedge at 0x1f93c5cbfd0>,
#   <matplotlib.patches.Wedge at 0x1f93c5d54e0>,
#   <matplotlib.patches.Wedge at 0x1f93c5d59b0>,
#   <matplotlib.patches.Wedge at 0x1f93c5d5e80>,
#   <matplotlib.patches.Wedge at 0x1f93c5de390>,
#   <matplotlib.patches.Wedge at 0x1f93c5de860>,
#   <matplotlib.patches.Wedge at 0x1f93c5ded30>,
#   <matplotlib.patches.Wedge at 0x1f93c5e9240>,
#   <matplotlib.patches.Wedge at 0x1f93c5e9710>,
#   <matplotlib.patches.Wedge at 0x1f93c5e9be0>,
#   <matplotlib.patches.Wedge at 0x1f93c5f10f0>,
#   <matplotlib.patches.Wedge at 0x1f93c5f15c0>,
#   <matplotlib.patches.Wedge at 0x1f93c5f1a90>,
#   <matplotlib.patches.Wedge at 0x1f93c5f1f60>,
#   <matplotlib.patches.Wedge at 0x1f93c5fc470>,
#   <matplotlib.patches.Wedge at 0x1f93c5fc940>,
#   <matplotlib.patches.Wedge at 0x1f93c5fce10>,
#   <matplotlib.patches.Wedge at 0x1f93c607320>,
#   <matplotlib.patches.Wedge at 0x1f93c6077f0>,
#   <matplotlib.patches.Wedge at 0x1f93c607cc0>,
#   <matplotlib.patches.Wedge at 0x1f93c6101d0>,
#   <matplotlib.patches.Wedge at 0x1f93c6106a0>,
#   <matplotlib.patches.Wedge at 0x1f93c610b70>,
#   <matplotlib.patches.Wedge at 0x1f93c618080>,
#   <matplotlib.patches.Wedge at 0x1f93c618550>,
#   <matplotlib.patches.Wedge at 0x1f93c618a20>,
#   <matplotlib.patches.Wedge at 0x1f93c618ef0>,
#   <matplotlib.patches.Wedge at 0x1f93c624400>,
#   <matplotlib.patches.Wedge at 0x1f93c6248d0>,
#   <matplotlib.patches.Wedge at 0x1f93c624da0>,
#   <matplotlib.patches.Wedge at 0x1f93c62c2b0>,
#   <matplotlib.patches.Wedge at 0x1f93c62c780>,
#   <matplotlib.patches.Wedge at 0x1f93c62cc50>,
#   <matplotlib.patches.Wedge at 0x1f93c637160>,
#   <matplotlib.patches.Wedge at 0x1f93c637630>,
#   <matplotlib.patches.Wedge at 0x1f93c637b00>,
#   <matplotlib.patches.Wedge at 0x1f93c637fd0>,
#   <matplotlib.patches.Wedge at 0x1f93c6404e0>,
#   <matplotlib.patches.Wedge at 0x1f93c6409b0>,
#   <matplotlib.patches.Wedge at 0x1f93c640e80>,
#   <matplotlib.patches.Wedge at 0x1f93c64b390>,
#   <matplotlib.patches.Wedge at 0x1f93c64b860>,
#   <matplotlib.patches.Wedge at 0x1f93c64bd30>,
#   <matplotlib.patches.Wedge at 0x1f93c655240>,
#   <matplotlib.patches.Wedge at 0x1f93c655710>,
#   <matplotlib.patches.Wedge at 0x1f93c655be0>,
#   <matplotlib.patches.Wedge at 0x1f93c65d0f0>,
#   <matplotlib.patches.Wedge at 0x1f93c65d5c0>,
#   <matplotlib.patches.Wedge at 0x1f93c65da90>,
#   <matplotlib.patches.Wedge at 0x1f93c65df60>,
#   <matplotlib.patches.Wedge at 0x1f93c668470>,
#   <matplotlib.patches.Wedge at 0x1f93c668940>,
#   <matplotlib.patches.Wedge at 0x1f93c668e10>,
#   <matplotlib.patches.Wedge at 0x1f93c670320>,
#   <matplotlib.patches.Wedge at 0x1f93c6707f0>,
#   <matplotlib.patches.Wedge at 0x1f93c670cc0>,
#   <matplotlib.patches.Wedge at 0x1f93c67b1d0>,
#   <matplotlib.patches.Wedge at 0x1f93c67b6a0>,
#   <matplotlib.patches.Wedge at 0x1f93c67bb70>,
#   <matplotlib.patches.Wedge at 0x1f93c685080>,
#   <matplotlib.patches.Wedge at 0x1f93c685550>,
#   <matplotlib.patches.Wedge at 0x1f93c685a20>,
#   <matplotlib.patches.Wedge at 0x1f93c685ef0>,
#   <matplotlib.patches.Wedge at 0x1f93c68d400>,
#   <matplotlib.patches.Wedge at 0x1f93c68d8d0>,
#   <matplotlib.patches.Wedge at 0x1f93c68dda0>,
#   <matplotlib.patches.Wedge at 0x1f93c69a2b0>,
#   <matplotlib.patches.Wedge at 0x1f93c69a780>,
#   <matplotlib.patches.Wedge at 0x1f93c69ac50>,
#   <matplotlib.patches.Wedge at 0x1f93c6a3160>,
#   <matplotlib.patches.Wedge at 0x1f93c6a3630>,
#   <matplotlib.patches.Wedge at 0x1f93c6a3b00>,
#   <matplotlib.patches.Wedge at 0x1f93c6a3fd0>,
#   <matplotlib.patches.Wedge at 0x1f93c6ac4e0>,
#   <matplotlib.patches.Wedge at 0x1f93c6ac9b0>,
#   <matplotlib.patches.Wedge at 0x1f93c6ace80>,
#   <matplotlib.patches.Wedge at 0x1f93c6b4390>,
#   <matplotlib.patches.Wedge at 0x1f93c6b4860>,
#   <matplotlib.patches.Wedge at 0x1f93c6b4d30>,
#   <matplotlib.patches.Wedge at 0x1f93c6c0240>,
#   <matplotlib.patches.Wedge at 0x1f93c6c0710>,
#   <matplotlib.patches.Wedge at 0x1f93c6c0be0>,
#   <matplotlib.patches.Wedge at 0x1f93c6c90f0>,
#   <matplotlib.patches.Wedge at 0x1f93c6c95c0>,
#   <matplotlib.patches.Wedge at 0x1f93c6c9a90>,
#   <matplotlib.patches.Wedge at 0x1f93c6c9f60>,
#   <matplotlib.patches.Wedge at 0x1f93c6d3470>,
#   <matplotlib.patches.Wedge at 0x1f93c6d3940>,
#   <matplotlib.patches.Wedge at 0x1f93c6d3e10>,
#   <matplotlib.patches.Wedge at 0x1f93c6dd320>,
#   <matplotlib.patches.Wedge at 0x1f93c6dd7f0>,
#   <matplotlib.patches.Wedge at 0x1f93c6ddcc0>,
#   <matplotlib.patches.Wedge at 0x1f93c6e81d0>,
#   <matplotlib.patches.Wedge at 0x1f93c6e86a0>,
#   <matplotlib.patches.Wedge at 0x1f93c6e8b70>,
#   <matplotlib.patches.Wedge at 0x1f93c6f1080>,
#   <matplotlib.patches.Wedge at 0x1f93c6f1550>,
#   <matplotlib.patches.Wedge at 0x1f93c6f1a20>,
#   <matplotlib.patches.Wedge at 0x1f93c6f1ef0>,
#   <matplotlib.patches.Wedge at 0x1f93c6fb400>,
#   <matplotlib.patches.Wedge at 0x1f93c6fb8d0>,
#   <matplotlib.patches.Wedge at 0x1f93c6fbda0>,
#   <matplotlib.patches.Wedge at 0x1f93c7032b0>,
#   <matplotlib.patches.Wedge at 0x1f93c703780>,
#   <matplotlib.patches.Wedge at 0x1f93c703c50>,
#   <matplotlib.patches.Wedge at 0x1f93c70d160>,
#   <matplotlib.patches.Wedge at 0x1f93c70d630>,
#   <matplotlib.patches.Wedge at 0x1f93c70db00>,
#   <matplotlib.patches.Wedge at 0x1f93c70dfd0>,
#   <matplotlib.patches.Wedge at 0x1f93c7184e0>,
#   <matplotlib.patches.Wedge at 0x1f93c7189b0>,
#   <matplotlib.patches.Wedge at 0x1f93c718e80>,
#   <matplotlib.patches.Wedge at 0x1f93c722390>,
#   <matplotlib.patches.Wedge at 0x1f93c722860>,
#   <matplotlib.patches.Wedge at 0x1f93c722d30>,
#   <matplotlib.patches.Wedge at 0x1f93c72b240>,
#   <matplotlib.patches.Wedge at 0x1f93c72b710>,
#   <matplotlib.patches.Wedge at 0x1f93c72bbe0>,
#   <matplotlib.patches.Wedge at 0x1f93c7340f0>,
#   <matplotlib.patches.Wedge at 0x1f93c7345c0>,
#   <matplotlib.patches.Wedge at 0x1f93c734a90>,
#   <matplotlib.patches.Wedge at 0x1f93c734f60>,
#   <matplotlib.patches.Wedge at 0x1f93c73f470>,
#   <matplotlib.patches.Wedge at 0x1f93c73f940>,
#   <matplotlib.patches.Wedge at 0x1f93c73fe10>,
#   <matplotlib.patches.Wedge at 0x1f93c747320>,
#   <matplotlib.patches.Wedge at 0x1f93c7477f0>,
#   <matplotlib.patches.Wedge at 0x1f93c747cc0>,
#   <matplotlib.patches.Wedge at 0x1f93c7521d0>,
#   <matplotlib.patches.Wedge at 0x1f93c7526a0>,
#   <matplotlib.patches.Wedge at 0x1f93c752b70>,
#   <matplotlib.patches.Wedge at 0x1f93c75b080>,
#   <matplotlib.patches.Wedge at 0x1f93c75b550>,
#   <matplotlib.patches.Wedge at 0x1f93c75ba20>,
#   <matplotlib.patches.Wedge at 0x1f93c75bef0>,
#   <matplotlib.patches.Wedge at 0x1f93c766400>,
#   <matplotlib.patches.Wedge at 0x1f93c7668d0>,
#   <matplotlib.patches.Wedge at 0x1f93c766da0>,
#   <matplotlib.patches.Wedge at 0x1f93c76f2b0>,
#   <matplotlib.patches.Wedge at 0x1f93c76f780>,
#   <matplotlib.patches.Wedge at 0x1f93c76fc50>,
#   <matplotlib.patches.Wedge at 0x1f93c779160>,
#   <matplotlib.patches.Wedge at 0x1f93c779630>,
#   <matplotlib.patches.Wedge at 0x1f93c779b00>,
#   <matplotlib.patches.Wedge at 0x1f93c779fd0>,
#   <matplotlib.patches.Wedge at 0x1f93c7844e0>,
#   <matplotlib.patches.Wedge at 0x1f93c7849b0>,
#   <matplotlib.patches.Wedge at 0x1f93c784e80>,
#   <matplotlib.patches.Wedge at 0x1f93c78b390>,
#   <matplotlib.patches.Wedge at 0x1f93c78b860>,
#   <matplotlib.patches.Wedge at 0x1f93c78bd30>,
#   <matplotlib.patches.Wedge at 0x1f93c797240>,
#   <matplotlib.patches.Wedge at 0x1f93c797710>,
#   <matplotlib.patches.Wedge at 0x1f93c797be0>,
#   <matplotlib.patches.Wedge at 0x1f93c79f0f0>,
#   <matplotlib.patches.Wedge at 0x1f93c79f5c0>,
#   <matplotlib.patches.Wedge at 0x1f93c79fa90>,
#   <matplotlib.patches.Wedge at 0x1f93c79ff60>,
#   <matplotlib.patches.Wedge at 0x1f93c7ab470>,
#   <matplotlib.patches.Wedge at 0x1f93c7ab940>,
#   <matplotlib.patches.Wedge at 0x1f93c7abe10>,
#   <matplotlib.patches.Wedge at 0x1f93c7b5320>,
#   <matplotlib.patches.Wedge at 0x1f93c7b57f0>,
#   <matplotlib.patches.Wedge at 0x1f93c7b5cc0>,
#   <matplotlib.patches.Wedge at 0x1f93c7be1d0>,
#   <matplotlib.patches.Wedge at 0x1f93c7be6a0>,
#   <matplotlib.patches.Wedge at 0x1f93c7beb70>,
#   <matplotlib.patches.Wedge at 0x1f93c7c7080>,
#   <matplotlib.patches.Wedge at 0x1f93c7c7550>,
#   <matplotlib.patches.Wedge at 0x1f93c7c7a20>,
#   <matplotlib.patches.Wedge at 0x1f93c7c7ef0>,
#   <matplotlib.patches.Wedge at 0x1f93c7d3400>,
#   <matplotlib.patches.Wedge at 0x1f93c7d38d0>],
#  [Text(0.4432287482203673, 1.0067513480254229, ''),
#   Text(-0.8853214723489367, 0.6528444612600395, ''),
#   Text(-1.0625777290351748, 0.28447947159408665, ''),
#   Text(-1.096156168702231, -0.09187847308290553, ''),
#   Text(-1.0118311560855027, -0.4315063285453361, ''),
#   Text(-0.8343943699505612, -0.7167886964753325, ''),
#   Text(-0.6441125604184011, -0.8916944597289206, ''),
#   Text(-0.5003875433913196, -0.9795980330823457, ''),
#   Text(-0.3827610803037202, -1.0312584328890257, ''),
#   Text(-0.29944988004664674, -1.0584563143276386, ''),
#   Text(-0.2284849939819939, -1.076008646584705, ''),
#   Text(-0.1607898761308621, -1.0881850098828887, ''),
#   Text(-0.09755730736845314, -1.095665355744635, ''),
#   Text(-0.039891040730264705, -1.0992764460632531, ''),
#   Text(0.009237741002775185, -1.0999612102893292, ''),
#   Text(0.0520664094886167, -1.0987670767742197, ''),
#   Text(0.09050734618656152, -1.0962702314148032, ''),
#   Text(0.12610411709109362, -1.092747798740714, ''),
#   Text(0.15884517099885306, -1.0884705837322133, ''),
#   Text(0.18950728384977653, -1.0835529471917282, ''),
#   Text(1.0964460020153246, -0.08835250231097581, ''),
#   Text(1.096508870078206, -0.08756881773677401, ''),
#   Text(1.0965711780027567, -0.08678508842909888, ''),
#   Text(1.096632925757148, -0.08600131478830715, ''),
#   Text(1.0966941133098367, -0.08521749721478107, ''),
#   Text(1.0967547406295657, -0.08443363610892445, ''),
#   Text(1.0968148076853643, -0.08364973187116419, ''),
#   Text(1.096874314446548, -0.08286578490194642, ''),
#   Text(1.0969332608827185, -0.08208179560174195, ''),
#   Text(1.0969916469637637, -0.08129776437104322, ''),
#   Text(1.0970494726598576, -0.08051369161036118, ''),
#   Text(1.0971067379414612, -0.07972957772023094, ''),
#   Text(1.0971634427793207, -0.0789454231012076, ''),
#   Text(1.097219587144469, -0.07816122815386807, ''),
#   Text(1.097275171008226, -0.07737699327880693, ''),
#   Text(1.0973301943421971, -0.07659271887664208, ''),
#   Text(1.097384657118274, -0.07580840534801161, ''),
#   Text(1.0974385593086353, -0.0750240530935707, ''),
#   Text(1.097491900885746, -0.0742396625139972, ''),
#   Text(1.0975446818223566, -0.07345523400998755, ''),
#   Text(1.097596902091505, -0.07267076798225859, ''),
#   Text(1.097648561666515, -0.0718862648315434, ''),
#   Text(1.097699660520997, -0.07110172495859686, ''),
#   Text(1.0977501986288478, -0.07031714876419178, ''),
#   Text(1.0978001759642504, -0.06953253664912036, ''),
#   Text(1.0978495925016745, -0.06874788901419032, ''),
#   Text(1.0978984482158765, -0.06796320626023039, ''),
#   Text(1.0979467430818988, -0.0671784887880873, ''),
#   Text(1.0979944770750707, -0.06639373699862251, ''),
#   Text(1.0980416501710077, -0.06560895129271803, ''),
#   Text(1.0980882623456125, -0.06482413207127212, ''),
#   Text(1.098134313575073, -0.06403927973520124, ''),
#   Text(1.0981798038358652, -0.06325439468543574, ''),
#   Text(1.0982247331047506, -0.062469477322925696, ''),
#   Text(1.0982691013587778, -0.06168452804863666, ''),
#   Text(1.0983129085752816, -0.060899547263551464, ''),
#   Text(1.0983561547318836, -0.060114535368666136, ''),
#   Text(1.0983988398064923, -0.05932949276499551, ''),
#   Text(1.0984409637773025, -0.0585444198535701, ''),
#   Text(1.0984825266227953, -0.05775931703543299, ''),
#   Text(1.0985235283217394, -0.056974184711645455, ''),
#   Text(1.0985639688531892, -0.056189023283282874, ''),
#   Text(1.0986038481964862, -0.05540383315143647, ''),
#   Text(1.0986431663312584, -0.05461861471720919, ''),
#   Text(1.098681923237421, -0.05383336838172138, ''),
#   Text(1.098720118895175, -0.05304809454610765, ''),
#   Text(1.0987577532850088, -0.052262793611513696, ''),
#   Text(1.0987948263876977, -0.051477465979102015, ''),
#   Text(1.0988313381843027, -0.05069211205004775, ''),
#   Text(1.0988672886561728, -0.04990673222554046, ''),
#   Text(1.0989026777849427, -0.04912132690678, ''),
#   Text(1.0989375055525343, -0.04833589649498218, ''),
#   Text(1.0989717719411567, -0.04755044139137467, ''),
#   Text(1.0990054769333049, -0.04676496199719869, ''),
#   Text(1.0990386205117613, -0.04597945871370497, ''),
#   Text(1.0999993678074622, -0.0011793316682646741, ''),
#   Text(1.0999999297495733, -0.0003931296653459756, '')])

# %% [markdown]
# #### __What was the share of the independent candidates__?

# %%
df3=df.groupby('Party').count().sum()
df3
# Out:
# State        8790
# Assembly     8790
# Candidate    8790
# Votes        8791
# dtype: int64

# %%
df2.Independent
# Out:
# 3235

# %%
print("Share= 3235/8790")
# Out:
# Share= 3235/8790

# %% [markdown]
# #### __Try to plot Scatter Plot of the Parameters you can__

# %%
plt.scatter(df1.Party,df1.Votes,c="green",alpha=0.5)
plt.xlabel("Party")
plt.show()

# %%
plt.scatter(df2['State'] ,df2.Votes,c="green",alpha=0.5)
plt.show()

# %% [markdown]
# #### __Is three dimensional plot possible for any set of parameters in this dataset?__

# %% [markdown]
# #### __Try the wordplot of the BJP Seats in each state__

# %%
d=df.groupby('Party').count()
d
# Out:
#                                                     State  Assembly  \
# Party
# AARAKSHAN VIRODHI PARTY                                 3         3
# AJSU Party                                             10        10
# Aadijan Mukti Sena                                      1         1
# Aadivasi Sena Party                                     2         2
# Aam Aadmi Party                                       431       431
# Aam Janata Party                                        1         1
# Aama Odisha Party                                       9         9
# Aazadi Ka Antim Aandolan Dal                            1         1
# Adarsh Manavtawadi Party                                1         1
# Adarsh Rashtriya Vikas Party                            7         7
# Adarsh Samaj Party                                      1         1
# Agar Jan Party                                          2         2
# Akhand Bharat Samaj Party                               1         1
# Akhil Bharat Hindu Mahasabha                            8         8
# Akhil Bharatiya Ashok Sena                              1         1
# Akhil Bharatiya Congress Dal (Ambedkar)                 2         2
# Akhil Bharatiya Hind Kranti Party                       1         1
# Akhil Bharatiya Jan Sangh                               4         4
# Akhil Bharatiya Manavata Paksha                         1         1
# Akhil Bharatiya Muslim League (Secular)                 5         5
# Akhil Bharatiya Rajarya Sabha                           1         1
# Akhil Bharatiya Samajwadi Congress                      1         1
# Akhil Bharatiya Shivsena Rashtrawadi                    1         1
# Akhil Bhartiya Aamjan Party                             1         1
# Akhil Bhartiya Jharkhand Party                          3         3
# Akhil Bhartiya Mithila Party                            2         2
# Akhil Bhartiya Vikas Congress Party                     1         1
# Akhil Rashtrawadi Party                                 1         1
# Al-Hind Party                                           4         4
# All India Anna Dravida Munnetra Kazhagam               40        40
# ...                                                   ...       ...
# Swabhimani Paksha                                       2         2
# Swaraj (J)                                              3         3
# Swarajya Party Of India                                 4         4
# Swatantra Samaj Party                                   1         1
# Tamil Nadu Makkal Congress                             10        10
# Telangana Communist Party of India                      1         1
# Telangana Loksatta Party                                2         2
# Telangana Rashtra Samithi                              17        17
# Telugu Desam                                           30        30
# The Lok Party of India                                  4         4
# The Religion of Man Revolving Political Party o...      1         1
# Thrinamool Tamil Nadu Congress                          1         1
# Tripura Pragatishil Gramin Congress                     2         2
# UTTARAKHAND PARIVARTAN PARTY                            1         1
# Ulzaipali Makkal Katchy                                 8         8
# Union Party of India                                    1         1
# United Communist Party of India                         3         3
# United Democratic Party                                 1         1
# Uttar Pradesh Republican Party                          1         1
