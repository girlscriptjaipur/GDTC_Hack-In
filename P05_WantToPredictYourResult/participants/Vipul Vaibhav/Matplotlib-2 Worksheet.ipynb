# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('https://query.data.world/s/bqrnga7n5nhps5yn5cbiarzdbqv2os')

# %%
df.head()
# Out:
#     Party                 Name    Type  \
# 0     CPI           Aziz Pasha  Others
# 1  CPI(M)     V K Ramachandran  Others
# 2     INC   Dr. Manmohan Singh  Others
# 3     INC  Dr. Manda Jagnathan  Others
# 4     INC     Prof. K.V.Thomas  Others
#
#                                              Address PAN Given    Amount  \
# 0                  16-B, Ferozeshah Road New Delhi-1         Y   3000000
# 1  No.1, First Floor Main Road Domlur Second Stag...         Y  10000000
# 2                   3, Motilal Nehru Place New Delhi         N    108000
# 3                        9,Firozshah Road New Delhi          N     54000
# 4                     17,Dr.B.R.Mehta Lane New Delhi         N     54000
#
#                                    Contribution Mode Financial Year   \
# 0                                               CASH         2010-11
# 1  000037, HDFC Bank Bengaluru, Dt. 16.03.2015, 5...         2014-15
# 2  Cheque, State Bank of India Parliament House N...         2014-15
# 3                              Through Bank Transfer         2011-12
# 4                              Through Bank Transfer         2011-12
#
#    Unnamed: 8  Unnamed: 9 Unnamed: 10  Unnamed: 11  Unnamed: 12 Unnamed: 13
# 0         NaN         NaN         NaN          NaN          NaN         NaN
# 1         NaN         NaN         NaN          NaN          NaN         NaN
# 2         NaN         NaN         NaN          NaN          NaN         NaN
# 3         NaN         NaN         NaN          NaN          NaN         NaN
# 4         NaN         NaN         NaN          NaN          NaN         NaN

# %% [markdown]
# ### Test of Freedom :  Get Creative

# %% [markdown]
# #### __Google and find some cool visualizations using matplotlib, you have complete freedom do some cool visualizations as you see fit with the data using this dataset. Remove the Nan Columns (Unnamed 8 to Unnamed 13) and create the magic__

# %% [markdown]
# [Matplotlib Cheat Sheet](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf)
#
# [Examples](https://python-graph-gallery.com/matplotlib/)

# %%
df.drop(['Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12','Unnamed: 13'], axis=1, inplace=True)
df.head()
# Out:
#     Party                 Name    Type  \
# 0     CPI           Aziz Pasha  Others
# 1  CPI(M)     V K Ramachandran  Others
# 2     INC   Dr. Manmohan Singh  Others
# 3     INC  Dr. Manda Jagnathan  Others
# 4     INC     Prof. K.V.Thomas  Others
#
#                                              Address PAN Given    Amount  \
# 0                  16-B, Ferozeshah Road New Delhi-1         Y   3000000
# 1  No.1, First Floor Main Road Domlur Second Stag...         Y  10000000
# 2                   3, Motilal Nehru Place New Delhi         N    108000
# 3                        9,Firozshah Road New Delhi          N     54000
# 4                     17,Dr.B.R.Mehta Lane New Delhi         N     54000
#
#                                    Contribution Mode Financial Year
# 0                                               CASH         2010-11
# 1  000037, HDFC Bank Bengaluru, Dt. 16.03.2015, 5...         2014-15
# 2  Cheque, State Bank of India Parliament House N...         2014-15
# 3                              Through Bank Transfer         2011-12
# 4                              Through Bank Transfer         2011-12

# %%
#Only interested in Party and Amount Column and Financial Year
df = df.iloc[:,[0,5,7]]
df.head()
# Out:
#     Party    Amount Financial Year
# 0     CPI   3000000         2010-11
# 1  CPI(M)  10000000         2014-15
# 2     INC    108000         2014-15
# 3     INC     54000         2011-12
# 4     INC     54000         2011-12

# %%
df = df.groupby(['Party','Financial Year ']).sum() 
df
# Out:
#                             Amount
# Party  Financial Year
# BJP    2003-04           116881973
#        2004-05           339521289
#        2005-06            36156111
#        2006-07            29550672
#        2007-08           249623653
#        2008-09           306057231
#        2009-10           823220133
#        2010-11           146253279
#        2011-12           334194113
#        2012-13           831924462
#        2013-14          1708636182
#        2014-15          4373506898
# CPI    2003-04              779148
#        2004-05              630000
#        2005-06             3988690
#        2006-07             1229400
#        2007-08             4125800
#        2008-09             2585000
#        2009-10             8667852
#        2010-11            10811465
#        2011-12             5982675
#        2012-13             3695449
#        2013-14            12281544
#        2014-15            13346675
# CPI(M) 2003-04              200000
#        2004-05              896355
#        2005-06              550000
#        2006-07             1124719
#        2007-08             7226116
#        2008-09             4155000
#        2009-10             3962049
#        2010-11            15357072
#        2011-12            23838657
#        2012-13            38139996
#        2013-14            20974666
#        2014-15            34197498
# INC    2003-04            28301101
#        2004-05           320555643
#        2005-06            59212492
#        2006-07           121273513
#        2007-08            78873451
#        2008-09           279018460
#        2009-10           840521238
#        2010-11            80205884
#        2011-12            95910664
#        2012-13           117166225
#        2013-14           595837728
#        2014-15          1414610950
# NCP    2007-08            10225000
#        2008-09            56091000
#        2009-10            30300000
#        2010-11             1355000
#        2011-12            21000000
#        2012-13              504000
#        2013-14           140200000
#        2014-15           388236419

# %%
df2.loc['BJP'] #Accessing the BJP account
# Out:
#                      Amount
# Financial Year
# 2003-04           116881973
# 2004-05           339521289
# 2005-06            36156111
# 2006-07            29550672
# 2007-08           249623653
# 2008-09           306057231
# 2009-10           823220133
# 2010-11           146253279
# 2011-12           334194113
# 2012-13           831924462
# 2013-14          1708636182
# 2014-15          4373506898

# %%
df_party = pd.DataFrame()
df_party['BJP'] = df.loc['BJP','Amount']
df_party['CPI'] = df.loc['CPI','Amount']
df_party['CPI(M)'] = df.loc['CPI(M)','Amount']
df_party['INC'] = df.loc['INC','Amount']
df_party['NCP'] = df.loc['NCP','Amount']
df_party
df_party.fillna(value=0,inplace=True)

# %%
df_party.plot(kind="area", figsize=(15,7))

# %%
df_party.plot(x=df_party['BJP'], y='Amount',kind="area", figsize=(15,7))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-aa9cfe56603a> in <module>
# ----> 1 df_party.plot(x=df_party['BJP'], y='Amount',kind="area", figsize=(15,7))
#
# ~\Anaconda2\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ~\Anaconda2\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# ~\Anaconda2\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1764                 if is_integer(x) and not data.columns.holds_integer():
#    1765                     x = data_cols[x]
# -> 1766                 elif not isinstance(data[x], ABCSeries):
#    1767                     raise ValueError("x must be a label or position")
#    1768                 data = data.set_index(x)
#
# ~\Anaconda2\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~\Anaconda2\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ~\Anaconda2\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: '[ 116881973  339521289   36156111   29550672  249623653  306057231\n  823220133  146253279  334194113  831924462 1708636182 4373506898] not in index'
