# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../csv_files/firstsem_cse.csv")

# %%
df.head()
# Out:
#            Student Name  EnrollMent No                SID  \
# 0              ABHISHEK      110102717  SID: 190000099690
# 1  ABHISHEK KUMAR VERMA      210102717  SID: 190000099691
# 2                ANJALI      510102717  SID: 190000099812
# 3        ANOOP PARASHAR      610102717  SID: 190000099813
# 4         ARSHWIN KUMAR      710102717  SID: 190000099814
#
#                 Scheme ID  AM-1 Internal  AM-1 External  AP-1 Internal  \
# 0  SchemeID: 190272015001             17             35             24
# 1  SchemeID: 190272015001             17             57             23
# 2  SchemeID: 190272015001             15             50             19
# 3  SchemeID: 190272015001              9             31             18
# 4  SchemeID: 190272015001             17             28             25
#
#    AP-1 External  MP Internal  MP External  ...  ET LAB External  \
# 0             50           25           30  ...               53
# ...

# %% [markdown]
# ### __Set The Column Student Name as the Index__

# %%
df = pd.read_csv("../csv_files/firstsem_cse.csv",index_col="Student Name")

# %%
# Out:
# range(0, 20)

# %% [markdown]
# ### Drop the Enrollment No, Columns SID,Scheme ID, ALL LAB SUBJECTS (LAB IN THEIR NAME) and Total Credits from the DataFrame df__
# Don't make new dataset save it to df as we have to do more operations that is dependent over it(If stuck better ask in the group)

# %%
list_del=['EnrollMent No','SID','Scheme ID','ET LAB External','MP LAB Internal','MP LAB External','FOC LAB Internal','FOC LAB External','ED LAB Internal','ED LAB External','AC LAB Internal','AC LAB External','Total Credits','AP-1 LAB Internal','AP-1 LAB External','ET LAB Internal']
df1=df.drop(list_del,axis=1)

# %%
df1.head(5)
# Out:
#                       AM-1 Internal  AM-1 External  AP-1 Internal  \
# Student Name
# ABHISHEK                         17             35             24
# ABHISHEK KUMAR VERMA             17             57             23
# ANJALI                           15             50             19
# ANOOP PARASHAR                    9             31             18
# ARSHWIN KUMAR                    17             28             25
#
#                       AP-1 External  MP Internal  MP External  ET Internal  \
# Student Name
# ABHISHEK                         50           25           30           22
# ABHISHEK KUMAR VERMA             64           22           47           17
# ANJALI                           59           17           38           15
# ANOOP PARASHAR                   31           20           46           13
# ARSHWIN KUMAR                    42           22           49           17
#
#                       ET External  HVPE External  FOC Internal  FOC External  \
# ...

# %% [markdown]
# ### __Add a Column Name Total Marks which will have total marks of each row (Summation of all marks obtained)__

# %%
df1['Total Marks']=df1.sum(axis=1)
df1
# Out:
#                         AM-1 Internal  AM-1 External  AP-1 Internal  \
# Student Name
# ABHISHEK                           17             35             24
# ABHISHEK KUMAR VERMA               17             57             23
# ANJALI                             15             50             19
# ANOOP PARASHAR                      9             31             18
# ARSHWIN KUMAR                      17             28             25
# ASHISH KUMAR CHOUDHARY             17             48             24
# AYUSH SINGH CHILWAL                17             60             23
# AYUSH YADAV                         4             21             15
# DIPANSHU KUMAR                     14             29             18
# GAURAV KUMAR                       14             41             19
# HARI OM PAL                        24             44             23
# HARSHIT SAINI                      13             50             21
# HIMANSHU                           19             22             17
# ...

# %%
df1.shape
# Out:
# (1653, 14)

# %%
df1.columns.get_loc("HVPE External")
# Out:
# 8

# %%
df1.insert(13,"Am-1 Total",100)
df1.insert(14,"Ap-1 Total",100)
df1.insert(15,"MP Total",100)
df1.insert(16,"ET Total",100)
df1.insert(17,"HVPE Total",100)
df1.insert(18,"FOC Total",100)
df1.insert(19,"AC Total",100)

# %%
df1.head(2)
df1.columns.get_loc("HVPE Total")
# Out:
# 17

# %%
list1=[i for i in range(0,14,2)]
print(list1)
# Out:
# [0, 2, 4, 6, 8, 10, 12]

# %%
df1.head(1)
# Out:
#               AM-1 Internal  AM-1 External  AP-1 Internal  AP-1 External  \
# Student Name
# ABHISHEK                 17             35             24             50
#
#               MP Internal  MP External  ET Internal  ET External  \
# Student Name
# ABHISHEK               25           30           22           36
#
#               FOC Internal  FOC External  AC Internal  AC External  \
# Student Name
# ABHISHEK                19            51           23           50
#
#               Am-1 Total  Ap-1 Total  MP Total  ET Total  HVPE Total  \
# Student Name
# ABHISHEK              52          74        55        58          90
#
#               FOC Total  AC Total  Total Marks
# Student Name
# ABHISHEK             74       100          472

# %%
list1=['AM-1 Internal', 'AM-1 External', 'AP-1 Internal', 'AP-1 External',
       'MP Internal', 'MP External', 'ET Internal', 'ET External',
        'FOC Internal', 'FOC External', 'AC Internal',
       'AC External']
list2=['Am-1 Total', 'Ap-1 Total', 'MP Total', 'ET Total',
        'FOC Total', 'AC Total']

for i ,j in zip(range(0,len(list1),2),range(len(list2))):
    df1[list2[j]]=df1[list1[i]]+df1[list1[i+1]]

# %%
df1.head(2)
# Out:
#                       AM-1 Internal  AM-1 External  AP-1 Internal  \
# Student Name
# ABHISHEK                         17             35             24
# ABHISHEK KUMAR VERMA             17             57             23
#
#                       AP-1 External  MP Internal  MP External  ET Internal  \
# Student Name
# ABHISHEK                         50           25           30           22
# ABHISHEK KUMAR VERMA             64           22           47           17
#
#                       ET External  FOC Internal  FOC External  AC Internal  \
# Student Name
# ABHISHEK                       36            19            51           23
# ABHISHEK KUMAR VERMA           57            19            65           24
#
#                       AC External  Am-1 Total  Ap-1 Total  MP Total  ET Total  \
# Student Name
# ABHISHEK                       50          52          74        55        58
# ABHISHEK KUMAR VERMA           63          74          87        69        74
#
# ...

# %% [markdown]
# ### __Combine all the columns__
# * Combine Columns of External and Internal Marks into one i.e AM-1 Internal and AM-1 External must be added and stored to another column named AM-1 Total(drop the AM-1 Internal and AM-1 External After that). Use any of the technique you like and do the same for all the subjects.
#
# ** __ATTENTION__ **
# * A subject named HVPE doesn't have internal marks.
#
#
# __Dataframe after this step must look like__
#
# | Student Name |AM-1 Total|AM-1 Total|AP-1 Total|MP Total|ET Total|HVPE Total| FOC Total|AC Total|Total Marks|
# |------|------|------|------|------|------|------|------|------|--|

# %%
df1=df1.drop(list1,axis=1)

# %%
df1.head(1)
# Out:
#              Student Name  Am-1 Total  Ap-1 Total  MP Total  ET Total  \
# Student Name
# ABHISHEK         ABHISHEK          52          74        55        58
#
#               HVPE Total  FOC Total  AC Total  Total Marks
# Student Name
# ABHISHEK              90         70        73          472

# %%
df1.drop("Student Name",axis=1)
# Out:
#                         Am-1 Total  Ap-1 Total  MP Total  ET Total  \
# Student Name
# ABHISHEK                        52          74        55        58
# ABHISHEK KUMAR VERMA            74          87        69        74
# ANJALI                          65          78        55        69
# ANOOP PARASHAR                  40          49        66        55
# ARSHWIN KUMAR                   45          67        71        71
# ASHISH KUMAR CHOUDHARY          65          83        66        65
# AYUSH SINGH CHILWAL             77          87        63        80
# AYUSH YADAV                     25          35        33        50
# DIPANSHU KUMAR                  43          42        54        59
# GAURAV KUMAR                    55          42        55        47
# HARI OM PAL                     68          68        76        72
# HARSHIT SAINI                   63          50        58        63
# HIMANSHU                        41          45        42        56
# ...

# %%
df1.head(1)
# Out:
#   Student Name  Am-1 Total  Ap-1 Total  MP Total  ET Total  HVPE Total  \
# 0     ABHISHEK          52          74        55        58          90
#
#    FOC Total  AC Total  Total Marks
# 0         70        73          472

# %%
df1=df1.reset_index(drop=True)
df1.head(1)
# Out:
#   Student Name  Am-1 Total  Ap-1 Total  MP Total  ET Total  HVPE Total  \
# 0     ABHISHEK          52          74        55        58          90
#
#    FOC Total  AC Total  Total Marks
# 0         70        73          472

# %% [markdown]
# ### __Find Mean Marks of All the subjects.__

# %%
df1.iloc[:,0:8].mean()
# Out:
# Am-1 Total    57.238355
# Ap-1 Total    60.275862
# MP Total      62.153660
# ET Total      58.385360
# HVPE Total    78.690865
# FOC Total     64.421658
# AC Total      63.170599
# dtype: float64

# %% [markdown]
# ### __Find Variance and Standard Deviation for each Subject and tell me what does it mean?__

# %%
df1.iloc[:,0:8].var()
# Out:
# Am-1 Total    235.736131
# Ap-1 Total    227.892377
# MP Total      208.844413
# ET Total      204.193418
# HVPE Total    149.752441
# FOC Total     124.297279
# AC Total      214.032622
# dtype: float64

# %%
df1.iloc[:,0:8].std()
# Out:
# Am-1 Total    15.353701
# Ap-1 Total    15.096105
# MP Total      14.451450
# ET Total      14.289626
# HVPE Total    12.237338
# FOC Total     11.148869
# AC Total      14.629854
# dtype: float64

# %%
## subjects with high variance and std tell that there is lot of dispersion in distribution of marks.
