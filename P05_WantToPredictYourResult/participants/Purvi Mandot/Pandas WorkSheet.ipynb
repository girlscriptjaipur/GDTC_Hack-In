# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("firstsem_cse.csv")

# %%
df
# Out:
#                 Student Name  EnrollMent No                SID  \
# 0                   ABHISHEK      110102717  SID: 190000099690
# 1       ABHISHEK KUMAR VERMA      210102717  SID: 190000099691
# 2                     ANJALI      510102717  SID: 190000099812
# 3             ANOOP PARASHAR      610102717  SID: 190000099813
# 4              ARSHWIN KUMAR      710102717  SID: 190000099814
# 5     ASHISH KUMAR CHOUDHARY      810102717  SID: 190000099815
# 6        AYUSH SINGH CHILWAL      910102717  SID: 190000099816
# 7                AYUSH YADAV     1010102717  SID: 190000099817
# 8             DIPANSHU KUMAR     1310102717  SID: 190000099820
# 9               GAURAV KUMAR     1410102717  SID: 190000099821
# 10               HARI OM PAL     1510102717  SID: 190000099822
# 11             HARSHIT SAINI     1610102717  SID: 190000099823
# 12                  HIMANSHU     1710102717  SID: 190000099824
# 13               ISHAAN JAIN     1810102717  SID: 190000099825
# ...

# %% [markdown]
# ### __Set The Column Student Name as the Index__

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("firstsem_cse.csv")
df=df.sort_values('Student Name')
df.set_index("Student Name",inplace=True)
df
# Out:
#                          EnrollMent No                SID  \
# Student Name
# AADITYA MAHINDRU           50120802717  SID: 190000099779
# AAKANKSHA DUBEY              114802717  SID: 190000099642
# AAKANKSHA SIROHI           35115602717  SID: 190000099198
# AAKASH GUPTA               40720802717  SID: 190000099855
# AAKASH MALIK               46014802717  SID: 190000100292
# AAKASH SHARMA                111502717  SID: 190000100176
# AARJA KAUR                   113202717  SID: 190000100480
# AARTI                      40555102717  SID: 190000099028
# AASHISH UPADHYAY             115002717  SID: 190000100191
# AASHUTOSH BHARDWAJ         35125502717  SID: 190000100306
# AASTHA                     41815002717  SID: 190000098861
# AASTHA GUPTA               50125502717  SID: 190000100262
# AAYUSH A RAINA               214802717  SID: 190000099643
# AAYUSH BHATNAGAR           40215002717  SID: 190000098845
# AAYUSH GEOL                50176802717  SID: 190000099883
# ...

# %% [markdown]
# ### __Drop the Enrollment No, Columns SID,Scheme ID, ALL LAB SUBJECTS (LAB IN THEIR NAME) and Total Credits from the DataFrame df__
# Don't make new dataset save it to df as we have to do more operations that is dependent over it(If stuck better ask in the group)

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("firstsem_cse.csv")
df=df.sort_values('Student Name')
df.set_index("Student Name",inplace=True)
df.drop(["ET LAB External","MP LAB Internal","FOC LAB Internal","FOC LAB External","ED LAB Internal","AP-1 LAB Internal","AP-1 LAB External","ET LAB Internal","MP LAB External","ED LAB External","AC LAB Internal","AC LAB External","Total Credits","SID","Scheme ID","EnrollMent No"],axis=1,inplace=True)
df
# Out:
#                          AM-1 Internal  AM-1 External  AP-1 Internal  \
# Student Name
# AADITYA MAHINDRU                    17             45             19
# AAKANKSHA DUBEY                     25             67             24
# AAKANKSHA SIROHI                    21             32             23
# AAKASH GUPTA                         7             51             10
# AAKASH MALIK                        25             44             23
# AAKASH SHARMA                       21             34             13
# AARJA KAUR                          14             39             18
# AARTI                               20             23             22
# AASHISH UPADHYAY                    22             51             23
# AASHUTOSH BHARDWAJ                  24             36             25
# AASTHA                              25             67             25
# AASTHA GUPTA                        23             43             23
# ...

# %% [markdown]
# ### __Add a Column Name Total Marks which will have total marks of each row (Summation of all marks obtained)__

# %%
df["Marks"]=df.sum(axis = 1, skipna = True)
df
# Out:
#                          AM-1 Internal  AM-1 External  AP-1 Internal  \
# Student Name
# AADITYA MAHINDRU                    17             45             19
# AAKANKSHA DUBEY                     25             67             24
# AAKANKSHA SIROHI                    21             32             23
# AAKASH GUPTA                         7             51             10
# AAKASH MALIK                        25             44             23
# AAKASH SHARMA                       21             34             13
# AARJA KAUR                          14             39             18
# AARTI                               20             23             22
# AASHISH UPADHYAY                    22             51             23
# AASHUTOSH BHARDWAJ                  24             36             25
# AASTHA                              25             67             25
# AASTHA GUPTA                        23             43             23
# ...

# %% [markdown]
# ### __Combine all the columns__
# * Combine Columns of External and Internal Marks into one i.e AM-1 Internal and AM-1 External must be added and stored to another column named AM-1 Total(drop the AM-1 Internal and AM-1 External After that). Use any of the technique you like and do the same for all the subjects.
#
# ** __ATTENTION__ **
# * A subject named HVPE doesn't have internal marks.
#
#
# __Dataframe after this step must look like__
#
# | Student Name |AM-1 Total|AM-1 Total|AP-1 Total|MP Total|ET Total|HVPE Total| FOC Total|AC Total|Total Marks|
# |------|------|------|------|------|------|------|------|------|--|

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("firstsem_cse.csv")
df.drop(["ET LAB External","MP LAB Internal","FOC LAB Internal","FOC LAB External","ED LAB Internal","AP-1 LAB Internal","AP-1 LAB External","ET LAB Internal","MP LAB External","ED LAB External","AC LAB Internal","AC LAB External","Total Credits","SID","Scheme ID","EnrollMent No"],axis=1,inplace=True)
df["Marks"]=df.sum(axis = 1, skipna = True)
df["AM-1 Total"]=df["AM-1 Internal"]+df["AM-1 External"]
df["AP-1 Total"]=df["AP-1 Internal"]+df["AP-1 External"]
df["MP Total"]=df["MP Internal"]+df["MP External"]
df["ET Total"]=df["ET Internal"]+df["ET External"]
df["FOC Total"]=df["FOC Internal"]+df["FOC External"]
df["AC Total"]=df["AC Internal"]+df["AC External"]
df.drop(["ET External","MP Internal","FOC Internal","FOC External","ET Internal","MP External","AM-1 Internal","AM-1 External","AP-1 Internal","AP-1 External","AC Internal","AC External"],axis=1,inplace=True)   
df
# Out:
#                 Student Name  HVPE External  Marks  AM-1 Total  AP-1 Total  \
# 0                   ABHISHEK             90    472          52          74
# 1       ABHISHEK KUMAR VERMA             89    564          74          87
# 2                     ANJALI             82    486          65          78
# 3             ANOOP PARASHAR             76    394          40          49
# 4              ARSHWIN KUMAR             85    472          45          67
# 5     ASHISH KUMAR CHOUDHARY             88    499          65          83
# 6        AYUSH SINGH CHILWAL             84    559          77          87
# 7                AYUSH YADAV             85    343          25          35
# 8             DIPANSHU KUMAR             77    384          43          42
# 9               GAURAV KUMAR             82    410          55          42
# 10               HARI OM PAL             87    524          68          68
# ...

# %% [markdown]
# ### __Find Mean Marks of All the subjects.__

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("firstsem_cse.csv")
df.drop(["ET LAB External","MP LAB Internal","FOC LAB Internal","FOC LAB External","ED LAB Internal","AP-1 LAB Internal","AP-1 LAB External","ET LAB Internal","MP LAB External","ED LAB External","AC LAB Internal","AC LAB External","Total Credits","SID","Scheme ID","EnrollMent No"],axis=1,inplace=True)
df["Marks"]=df.sum(axis = 1, skipna = True)
df["AM-1 Total"]=df["AM-1 Internal"]+df["AM-1 External"]
df["AP-1 Total"]=df["AP-1 Internal"]+df["AP-1 External"]
df["MP Total"]=df["MP Internal"]+df["MP External"]
df["ET Total"]=df["ET Internal"]+df["ET External"]
df["FOC Total"]=df["FOC Internal"]+df["FOC External"]
df["AC Total"]=df["AC Internal"]+df["AC External"]
df.drop(["ET External","MP Internal","FOC Internal","FOC External","ET Internal","MP External","AM-1 Internal","AM-1 External","AP-1 Internal","AP-1 External","AC Internal","AC External"],axis=1,inplace=True)   

df["AM-1 Total"].mean()
# Out:
# 57.238354506957045

# %%
df["HVPE External"].mean()
# Out:
# 78.6908650937689

# %%
df["AP-1 Total"].mean()
# Out:
# 60.275862068965516

# %%
df["FOC Total"].mean()
# Out:
# 64.42165759225651

# %%
df["ET Total"].mean()
# Out:
# 58.38535995160314

# %%
df["AC Total"].mean()
# Out:
# 63.17059891107078

# %%
df["AM-1 Total"].std()
# Out:
# 235.73613094688716

# %%
df["HVPE External"].std()
# Out:
# 12.237337975068403

# %%
df["AP-1 Total"].std()
# Out:
# 15.096104698100879

# %%
df["FOC Total"].std()
# Out:
# 11.148868949305474

# %%
df["ET Total"].std()
# Out:
# 14.289626219761727

# %%
df["AC Total"].std()
# Out:
# 14.629853783805181

# %%
df["AM-1 Total"].var()
# Out:
# 235.73613094688716

# %%
df["HVPE External"].var()
# Out:
# 149.75244071605124

# %%
df["AP-1 Total"].var()
# Out:
# 227.89237705602343

# %%
df["FOC Total"].var()
# Out:
# 124.29727884878773

# %%
df["ET Total"].var()
# Out:
# 204.19341750050182

# %%
df["AC Total"].var()
# Out:
# 214.0326217355188

# %% [markdown]
# ### __Find Variance and Standard Deviation for each Subject and tell me what does it mean?__

# %%
#calculated above
they mean how much the data varies from average. More standard variation and variation show that the marks are more spread out.
