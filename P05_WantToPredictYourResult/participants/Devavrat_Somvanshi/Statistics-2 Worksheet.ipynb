# %% [markdown]
# # Worksheet - 2

# %% [markdown]
# #### __What do one standard deviation means in normal distribution? Explain using code or way you prefer?__

# %% [markdown]
# Standard deviation is actully the measurement of how data is distributed with respect to mean.

# %% [markdown]
# #### __Create a normal distribution of mean 100 and standard deviation 20 and another of mean 100 and standard deviation 10 can you state some differences?__

# %% [raw]
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# from scipy.stats import uniform
# from scipy.stats import gamma

# %%
normal_vals1 = np.random.normal(100,20,1000)
normal_vals2 = np.random.normal(100,10,1000)
plt.figure(figsize=(15,7)) 
sns.distplot(normal_vals1)
sns.distplot(normal_vals2)
# Out:
# N:\anaconda\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# N:\anaconda\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [raw]
# As we can see from digram that the range of outliers in first fig is much more greater than second one(i.e
# with 10 std variation) )

# %% [markdown]
# #### __Plot the both curves and observe the difference__ (Good Task)

# %%
##Above

# %% [markdown]
# #### __Find 3 type of more distributions and explain them here other than normal distribution. Try to plot them it only takes 2 easy lines:__
# import matplotlib.pyplot as plt<br>
# import seaborn as sns
#
#
# plt.figure(figsize=(15,7)) #<================ This line sets the figure size so use it before every figure plotting<br>
# sns.distplot(normal_vals) #<====== this create a plot (kind of histogram) for the values just put whatever variable you have
#
# plug your values in normal_vals and you will have your histogram

# %%
#UNIFORM DISTRIBUTION
n = 10000
start = 10
width = 20
data_uniform = uniform.rvs(size=n, loc = start, scale=width)
plt.figure(figsize=(15,7))
sns.distplot(data_uniform)
# Out:
# N:\anaconda\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [raw]
# Here all numbers are uniformally distributed hence they should be assigned with equal probabilty, that means
# the area under the curve should e equal to 1. to acheive this if are taking range from 10 to 20, the max value oin y axis
# should be 1/(30-10).

# %%
#Gamma Distribution
data_gamma = gamma.rvs(a=5, size=10000)
plt.figure(figsize=(15,7))
sns.distplot(data_gamma)
# Out:
# N:\anaconda\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#Gamma/Exponential Distribution
data_gamma = gamma.rvs(a=1, size=10000)
plt.figure(figsize=(15,7))
sns.distplot(data_gamma)
# Out:
# N:\anaconda\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [raw]
# Here when we use a>1 we will get gamma distribution buyt
# for a=1 we will be getting exponential distribution
