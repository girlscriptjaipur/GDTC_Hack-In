# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('https://query.data.world/s/bqrnga7n5nhps5yn5cbiarzdbqv2os')

# %%
df.head()
# Out:
#     Party                 Name    Type  \
# 0     CPI           Aziz Pasha  Others
# 1  CPI(M)     V K Ramachandran  Others
# 2     INC   Dr. Manmohan Singh  Others
# 3     INC  Dr. Manda Jagnathan  Others
# 4     INC     Prof. K.V.Thomas  Others
#
#                                              Address PAN Given    Amount  \
# 0                  16-B, Ferozeshah Road New Delhi-1         Y   3000000
# 1  No.1, First Floor Main Road Domlur Second Stag...         Y  10000000
# 2                   3, Motilal Nehru Place New Delhi         N    108000
# 3                        9,Firozshah Road New Delhi          N     54000
# 4                     17,Dr.B.R.Mehta Lane New Delhi         N     54000
#
#                                    Contribution Mode Financial Year   \
# 0                                               CASH         2010-11
# 1  000037, HDFC Bank Bengaluru, Dt. 16.03.2015, 5...         2014-15
# 2  Cheque, State Bank of India Parliament House N...         2014-15
# ...

# %% [markdown]
# ### Test of Freedom :  Get Creative

# %% [markdown]
# #### __Google and find some cool visualizations using matplotlib, you have complete freedom do some cool visualizations as you see fit with the data using this dataset. Remove the Nan Columns (Unnamed 8 to Unnamed 13) and create the magic__

# %% [markdown]
# [Matplotlib Cheat Sheet](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf)
#
# [Examples](https://python-graph-gallery.com/matplotlib/)

# %%
df=df.drop(['Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12','Unnamed: 13'],axis=1)

# %%
df
# Out:
#         Party                                   Name    Type  \
# 0         CPI                             Aziz Pasha  Others
# 1      CPI(M)                       V K Ramachandran  Others
# 2         INC                     Dr. Manmohan Singh  Others
# 3         INC                    Dr. Manda Jagnathan  Others
# 4         INC                       Prof. K.V.Thomas  Others
# 5         BJP                        Sweta Chyouksey  Others
# 6         BJP                      Uma Shankar Gupta  Others
# 7         BJP         Parshwanath Bhakti Vihar Trust  Others
# 8         BJP             Anand Construction Company  Others
# 9         INC                          Kamal Kashore  Others
# 10        BJP                             R.V Pandit  Others
# 11        BJP                         A & T Infracon  Others
# 12        BJP         A 2 Z online  Services Pvt.Ltd  Others
# 13        BJP         A 2 Z online  Services Pvt.Ltd  Others
# ...

# %%
plt.hist(df['Amount'],density=True)
# Out:
# (array([1.99691311e-08, 1.47351912e-11, 2.94703824e-12, 8.84111471e-12,
#         1.47351912e-12, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 2.94703824e-12]),
#  array([1.87500000e+03, 5.00016875e+07, 1.00001500e+08, 1.50001312e+08,
#         2.00001125e+08, 2.50000938e+08, 3.00000750e+08, 3.50000562e+08,
#         4.00000375e+08, 4.50000188e+08, 5.00000000e+08]),
#  <a list of 10 Patch objects>)

# %%
plt.style.use('dark_background')
plt.hist(df['Amount'],density=True,color='orange')
# Out:
# (array([1.99691311e-08, 1.47351912e-11, 2.94703824e-12, 8.84111471e-12,
#         1.47351912e-12, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 2.94703824e-12]),
#  array([1.87500000e+03, 5.00016875e+07, 1.00001500e+08, 1.50001312e+08,
#         2.00001125e+08, 2.50000938e+08, 3.00000750e+08, 3.50000562e+08,
#         4.00000375e+08, 4.50000188e+08, 5.00000000e+08]),
#  <a list of 10 Patch objects>)

# %%
plt.tick_params(axis='x', colors='red', direction='out', length=13, width=3)
plt.tick_params(axis='y', colors='red', direction='out', length=13, width=3)
plt.suptitle("A 2D histogram\n", fontsize=18, y=1.02)
plt.title("Amount", color="grey", style='italic')


plt.hist(df['Amount'],density=True,color='orange')
# Out:
# (array([1.99691311e-08, 1.47351912e-11, 2.94703824e-12, 8.84111471e-12,
#         1.47351912e-12, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 2.94703824e-12]),
#  array([1.87500000e+03, 5.00016875e+07, 1.00001500e+08, 1.50001312e+08,
#         2.00001125e+08, 2.50000938e+08, 3.00000750e+08, 3.50000562e+08,
#         4.00000375e+08, 4.50000188e+08, 5.00000000e+08]),
#  <a list of 10 Patch objects>)

# %%
plt.tick_params(axis='x', colors='red', direction='out', length=13, width=3)
plt.tick_params(axis='y', colors='red', direction='out', length=13, width=3)
plt.suptitle("A 2D histogram\n", fontsize=18, y=1.02)
plt.title("Amount", color="grey", style='italic')


plt.hist(df['Amount'],density=True,color='orange',alpha=0.7)
# Out:
# (array([1.99691311e-08, 1.47351912e-11, 2.94703824e-12, 8.84111471e-12,
#         1.47351912e-12, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 2.94703824e-12]),
#  array([1.87500000e+03, 5.00016875e+07, 1.00001500e+08, 1.50001312e+08,
#         2.00001125e+08, 2.50000938e+08, 3.00000750e+08, 3.50000562e+08,
#         4.00000375e+08, 4.50000188e+08, 5.00000000e+08]),
#  <a list of 10 Patch objects>)

# %%
plt.xlabel('x', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
plt.ylabel('y', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')

plt.tick_params(axis='x', colors='red', direction='out', length=13, width=3)
plt.tick_params(axis='y', colors='red', direction='out', length=13, width=3)
plt.suptitle("A 2D histogram\n", fontsize=18, y=1.02)
plt.title("Amount", color="grey", style='italic')


plt.hist(df['Amount'],density=True,color='orange',alpha=0.7)
# Out:
# (array([1.99691311e-08, 1.47351912e-11, 2.94703824e-12, 8.84111471e-12,
#         1.47351912e-12, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 2.94703824e-12]),
#  array([1.87500000e+03, 5.00016875e+07, 1.00001500e+08, 1.50001312e+08,
#         2.00001125e+08, 2.50000938e+08, 3.00000750e+08, 3.50000562e+08,
#         4.00000375e+08, 4.50000188e+08, 5.00000000e+08]),
#  <a list of 10 Patch objects>)

# %%
plt.xlabel('x', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
plt.ylabel('y', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')

plt.tick_params(axis='x', colors='red', direction='out', length=13, width=3)
plt.tick_params(axis='y', colors='red', direction='out', length=13, width=3)
plt.suptitle("A 2D histogram\n", fontsize=18, y=1.02)
plt.title("Amount", color="grey", style='italic')


plt.hist(df['Amount'],density=True,color='orange',alpha=0.7)
# Out:
# (array([1.99691311e-08, 1.47351912e-11, 2.94703824e-12, 8.84111471e-12,
#         1.47351912e-12, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 2.94703824e-12]),
#  array([1.87500000e+03, 5.00016875e+07, 1.00001500e+08, 1.50001312e+08,
#         2.00001125e+08, 2.50000938e+08, 3.00000750e+08, 3.50000562e+08,
#         4.00000375e+08, 4.50000188e+08, 5.00000000e+08]),
#  <a list of 10 Patch objects>)

# %%
plt.xlabel('x', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')
plt.ylabel('y', fontweight='bold', color = 'blue', fontsize='17', horizontalalignment='center')

plt.tick_params(axis='x', colors='red', direction='out', length=13, width=3)
plt.tick_params(axis='y', colors='red', direction='out', length=13, width=3)
plt.suptitle("A 2D histogram\n", fontsize=18, y=1.02)
plt.title("Amount", color="grey", style='italic')


plt.hist(df['Amount'],density=True,color='orange',alpha=0.7)

plt.subplots_adjust(top=0.5)
