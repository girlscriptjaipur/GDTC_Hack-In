# %%
import numpy as np
import pandas as pd

# %%
# !pip install numpy
# !pip install pandas

# %%
df = pd.read_csv("C:/Users/dell/GDTC_Hack-In/P05_WantToPredictYourResult/csv_files/firstsem_cse.csv")

# %%
df.head()
# Out:
#            Student Name  EnrollMent No                SID  \
# 0              ABHISHEK      110102717  SID: 190000099690
# 1  ABHISHEK KUMAR VERMA      210102717  SID: 190000099691
# 2                ANJALI      510102717  SID: 190000099812
# 3        ANOOP PARASHAR      610102717  SID: 190000099813
# 4         ARSHWIN KUMAR      710102717  SID: 190000099814
#
#                 Scheme ID  AM-1 Internal  AM-1 External  AP-1 Internal  \
# 0  SchemeID: 190272015001             17             35             24
# 1  SchemeID: 190272015001             17             57             23
# 2  SchemeID: 190272015001             15             50             19
# 3  SchemeID: 190272015001              9             31             18
# 4  SchemeID: 190272015001             17             28             25
#
#    AP-1 External  MP Internal  MP External  ...  ET LAB External  \
# 0             50           25           30  ...               53
# ...

# %% [markdown]
# ### __Set The Column Student Name as the Index__

# %%
df = pd.read_csv("C:/Users/dell/GDTC_Hack-In/P05_WantToPredictYourResult/csv_files/firstsem_cse.csv",index_col="Student Name")

# %%
df
# Out:
#                         EnrollMent No                SID  \
# Student Name
# ABHISHEK                    110102717  SID: 190000099690
# ABHISHEK KUMAR VERMA        210102717  SID: 190000099691
# ANJALI                      510102717  SID: 190000099812
# ANOOP PARASHAR              610102717  SID: 190000099813
# ARSHWIN KUMAR               710102717  SID: 190000099814
# ASHISH KUMAR CHOUDHARY      810102717  SID: 190000099815
# AYUSH SINGH CHILWAL         910102717  SID: 190000099816
# AYUSH YADAV                1010102717  SID: 190000099817
# DIPANSHU KUMAR             1310102717  SID: 190000099820
# GAURAV KUMAR               1410102717  SID: 190000099821
# HARI OM PAL                1510102717  SID: 190000099822
# HARSHIT SAINI              1610102717  SID: 190000099823
# HIMANSHU                   1710102717  SID: 190000099824
# ISHAAN JAIN                1810102717  SID: 190000099825
# LAKSHAY MEENA              2010102717  SID: 190000099739
# ...

# %% [markdown]
# ### __Drop the Enrollment No, Columns SID,Scheme ID, ALL LAB SUBJECTS (LAB IN THEIR NAME) and Total Credits from the DataFrame df__
# Don't make new dataset save it to df as we have to do more operations that is dependent over it(If stuck better ask in the group)

# %%
df = df.drop(['EnrollMent No','SID','Scheme ID','ET LAB External','MP LAB Internal','MP LAB External','FOC LAB Internal','FOC LAB External','ED LAB Internal','ED LAB External','AC LAB Internal','AC LAB External','Total Credits'],axis=1)

# %%
df
# Out:
#                         AM-1 Internal  AM-1 External  AP-1 Internal  \
# Student Name
# ABHISHEK                           17             35             24
# ABHISHEK KUMAR VERMA               17             57             23
# ANJALI                             15             50             19
# ANOOP PARASHAR                      9             31             18
# ARSHWIN KUMAR                      17             28             25
# ASHISH KUMAR CHOUDHARY             17             48             24
# AYUSH SINGH CHILWAL                17             60             23
# AYUSH YADAV                         4             21             15
# DIPANSHU KUMAR                     14             29             18
# GAURAV KUMAR                       14             41             19
# HARI OM PAL                        24             44             23
# HARSHIT SAINI                      13             50             21
# HIMANSHU                           19             22             17
# ...

# %%
df=df.drop(['AP-1 LAB Internal','AP-1 LAB External','ET LAB Internal'],axis=1)

# %%
df
# Out:
#                         AM-1 Internal  AM-1 External  AP-1 Internal  \
# Student Name
# ABHISHEK                           17             35             24
# ABHISHEK KUMAR VERMA               17             57             23
# ANJALI                             15             50             19
# ANOOP PARASHAR                      9             31             18
# ARSHWIN KUMAR                      17             28             25
# ASHISH KUMAR CHOUDHARY             17             48             24
# AYUSH SINGH CHILWAL                17             60             23
# AYUSH YADAV                         4             21             15
# DIPANSHU KUMAR                     14             29             18
# GAURAV KUMAR                       14             41             19
# HARI OM PAL                        24             44             23
# HARSHIT SAINI                      13             50             21
# HIMANSHU                           19             22             17
# ...

# %% [markdown]
# ### __Add a Column Name Total Marks which will have total marks of each row (Summation of all marks obtained)__

# %%
total=df.sum(axis=1)

# %%
df["Total Marks"]=total

# %%
df
# Out:
#                         AM-1 Internal  AM-1 External  AP-1 Internal  \
# Student Name
# ABHISHEK                           17             35             24
# ABHISHEK KUMAR VERMA               17             57             23
# ANJALI                             15             50             19
# ANOOP PARASHAR                      9             31             18
# ARSHWIN KUMAR                      17             28             25
# ASHISH KUMAR CHOUDHARY             17             48             24
# AYUSH SINGH CHILWAL                17             60             23
# AYUSH YADAV                         4             21             15
# DIPANSHU KUMAR                     14             29             18
# GAURAV KUMAR                       14             41             19
# HARI OM PAL                        24             44             23
# HARSHIT SAINI                      13             50             21
# HIMANSHU                           19             22             17
# ...

# %% [markdown]
# ### __Combine all the columns__
# * Combine Columns of External and Internal Marks into one i.e AM-1 Internal and AM-1 External must be added and stored to another column named AM-1 Total(drop the AM-1 Internal and AM-1 External After that). Use any of the technique you like and do the same for all the subjects.
#
# ** __ATTENTION__ **
# * A subject named HVPE doesn't have internal marks.
#
#
# __Dataframe after this step must look like__
#
# | Student Name |AM-1 Total|AM-1 Total|AP-1 Total|MP Total|ET Total|HVPE Total| FOC Total|AC Total|Total Marks|
# |------|------|------|------|------|------|------|------|------|--|

# %%
df['AM-1 Total'] = df['AM-1 Internal'] + df['AM-1 External'] 
df['AP-1 Total'] = df['AP-1 Internal'] + df['AP-1 External'] 
df['MP Total'] = df['MP Internal'] + df['MP External'] 
df['ET Total'] = df['ET Internal'] + df['ET External']
df['HVPE Total']=df['HVPE External']
df['FOC Total'] = df['FOC Internal'] + df['FOC External'] 
df['AC Total'] = df['AC Internal'] + df['AC External']

# %%
df
# Out:
#                         AM-1 Internal  AM-1 External  AP-1 Internal  \
# Student Name
# ABHISHEK                           17             35             24
# ABHISHEK KUMAR VERMA               17             57             23
# ANJALI                             15             50             19
# ANOOP PARASHAR                      9             31             18
# ARSHWIN KUMAR                      17             28             25
# ASHISH KUMAR CHOUDHARY             17             48             24
# AYUSH SINGH CHILWAL                17             60             23
# AYUSH YADAV                         4             21             15
# DIPANSHU KUMAR                     14             29             18
# GAURAV KUMAR                       14             41             19
# HARI OM PAL                        24             44             23
# HARSHIT SAINI                      13             50             21
# HIMANSHU                           19             22             17
# ...

# %%
df=df.drop(['AM-1 Internal','AM-1 External','AP-1 Internal','AP-1 External','MP Internal','MP External','ET Internal','ET External','HVPE External','FOC Internal','FOC External','AC Internal','AC External'],axis=1)

# %%
df
# Out:
#                         Total Marks  AM-1 Total  AP-1 Total  MP Total  \
# Student Name
# ABHISHEK                        472          52          74        55
# ABHISHEK KUMAR VERMA            564          74          87        69
# ANJALI                          486          65          78        55
# ANOOP PARASHAR                  394          40          49        66
# ARSHWIN KUMAR                   472          45          67        71
# ASHISH KUMAR CHOUDHARY          499          65          83        66
# AYUSH SINGH CHILWAL             559          77          87        63
# AYUSH YADAV                     343          25          35        33
# DIPANSHU KUMAR                  384          43          42        54
# GAURAV KUMAR                    410          55          42        55
# HARI OM PAL                     524          68          68        76
# HARSHIT SAINI                   445          63          50        58
# ...

# %%
 df = df[['AM-1 Total','AP-1 Total','MP Total','ET Total','HVPE Total','FOC Total','AC Total','Total Marks']]

# %%
df
# Out:
#                         AM-1 Total  AP-1 Total  MP Total  ET Total  \
# Student Name
# ABHISHEK                        52          74        55        58
# ABHISHEK KUMAR VERMA            74          87        69        74
# ANJALI                          65          78        55        69
# ANOOP PARASHAR                  40          49        66        55
# ARSHWIN KUMAR                   45          67        71        71
# ASHISH KUMAR CHOUDHARY          65          83        66        65
# AYUSH SINGH CHILWAL             77          87        63        80
# AYUSH YADAV                     25          35        33        50
# DIPANSHU KUMAR                  43          42        54        59
# GAURAV KUMAR                    55          42        55        47
# HARI OM PAL                     68          68        76        72
# HARSHIT SAINI                   63          50        58        63
# HIMANSHU                        41          45        42        56
# ...

# %% [markdown]
# ### __Find Mean Marks of All the subjects.__

# %%
df.mean(axis=0)
# Out:
# AM-1 Total      57.238355
# AP-1 Total      60.275862
# MP Total        62.153660
# ET Total        58.385360
# HVPE Total      78.690865
# FOC Total       64.421658
# AC Total        63.170599
# Total Marks    444.336358
# dtype: float64

# %% [markdown]
# ### __Find Variance and Standard Deviation for each Subject and tell me what does it mean?__

# %%
df.var(axis=0) #Variance is a measurement of the spread between numbers in a data set
# Out:
# AM-1 Total      235.736131
# AP-1 Total      227.892377
# MP Total        208.844413
# ET Total        204.193418
# HVPE Total      149.752441
# FOC Total       124.297279
# AC Total        214.032622
# Total Marks    5815.464277
# dtype: float64

# %%
df.std(axis=0) #SD shows how much variation of the mean exists
# Out:
# AM-1 Total     15.353701
# AP-1 Total     15.096105
# MP Total       14.451450
# ET Total       14.289626
# HVPE Total     12.237338
# FOC Total      11.148869
# AC Total       14.629854
# Total Marks    76.259191
# dtype: float64
