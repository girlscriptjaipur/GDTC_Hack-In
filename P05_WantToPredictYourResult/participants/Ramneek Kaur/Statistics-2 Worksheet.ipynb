# %% [markdown]
# Worksheet - 2

# %% [markdown]
# What do one standard deviation means in normal distribution? Explain using code or way you prefer?__

# %% [markdown]
# One standard deviation means 68% of the observations lie within 1 standard deviation of the mean. The standard normal distribution is a normal distribution with a mean of zero and standard deviation of 1.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
normal_vals = np.random.normal(0,1,1000)

# %%
normal_vals.mean()
# Out:
# 0.023805053723438635

# %%
normal_vals.var()
# Out:
# 0.9824901822533963

# %%
normal_vals.std()
# Out:
# 0.9912064276695326

# %%
normal_vals
# Out:
# array([129.20889677, 126.12236581, 116.17030951, 115.93124667,
#         51.69281719,  75.76549314,  82.50517505,  70.58300668,
#         88.19965027, 117.04296486, 103.96349152, 111.1169898 ,
#         81.30720234, 124.04589312,  87.1724344 , 125.99543704,
#        116.51663938,  83.05179233,  85.96964386, 102.86050381,
#         84.79824627,  89.47430474,  99.75339374, 100.34013115,
#        134.3986085 ,  80.51767883,  84.9343365 ,  88.40963074,
#         84.43625943, 120.13287597, 108.6863802 ,  93.11445021,
#         96.01144928,  83.32207937,  95.66356082, 132.56371103,
#         73.64364186,  87.31722727, 109.99423768, 103.112012  ,
#        101.8466186 ,  96.09572001, 110.05560781,  87.66215798,
#         91.29507656, 126.24440468, 119.58658972,  73.67756427,
#        120.76792099, 113.03740647,  87.41244162,  90.50843958,
#         73.48998387,  61.82998792,  77.7629016 , 126.64473735,
#        103.83976825, 133.78231866,  69.80925435,  95.88403029,
# ...

# %% [markdown]
# #### __Create a normal distribution of mean 100 and standard deviation 20 and another of mean 100 and standard deviation 10 can you state some differences?__

# %%
normal_vals = np.random.normal(100,20,1000)

# %%
normal_vals.mean()
# Out:
# 100.1059074110577

# %%
normal_vals.std()
# Out:
# 19.68150543567159

# %%
normal_vals
# Out:
# array([ 69.86804688,  92.41360407,  71.74848744, 107.80575339,
#         72.02854325,  89.83462153, 124.7946656 ,  97.0810155 ,
#         91.86835336,  68.72426744, 123.37525847, 104.28854383,
#         95.73136194,  93.32278258, 102.48558704,  79.83034932,
#        117.18179087,  88.9556556 ,  80.91033108, 105.29593993,
#        112.16260305,  98.29760216,  83.27141408, 116.19365158,
#        124.24665577,  98.66196399, 119.82084431,  90.27386435,
#        109.08796189,  65.77267106, 104.31932919, 102.17159329,
#         75.07476666, 103.77455158,  85.08129526,  96.06993267,
#        121.97768422,  95.05344546,  91.13811688,  92.58938798,
#        107.6868712 , 136.80655753, 123.78844463, 150.48258519,
#        130.84330701,  95.08654779,  95.43360912, 109.12301818,
#        104.39806448, 132.99384046, 107.63206708,  99.02014771,
#        118.36116272, 109.31758953, 111.02961424, 105.90042273,
#        118.78188875,  95.76655311, 108.12886732, 129.07235708,
# ...

# %%
normal_vals = np.random.normal(100,10,1000)

# %%
normal_vals.mean()
# Out:
# 100.12481876439121

# %%
normal_vals.std()
# Out:
# 9.909340402784071

# %%
normal_vals
# Out:
# array([ 93.98743665, 107.86898493, 103.19439469,  93.92729197,
#        104.01389146,  90.75682016,  90.31776293,  96.58616057,
#        101.41473065, 103.11721074, 109.32811176, 110.32946978,
#        105.83981349, 110.91006699,  96.98211601, 106.46839962,
#         97.03819213, 106.99019185,  97.3096682 , 101.87555373,
#        110.94387931,  95.24983587, 102.34195789,  92.14068687,
#         99.37921209, 101.0811737 ,  96.12233899,  92.83436971,
#         93.82843168,  91.100881  , 110.11711326,  95.26228968,
#        107.3189693 , 121.20397638,  90.49473121, 121.13731334,
#        104.52771105, 100.74221719,  86.24461808, 113.04950531,
#        105.54321751, 102.04240555,  92.55362704, 101.84720138,
#        110.75142566, 102.57206516, 106.68581852, 101.47874292,
#        104.22639976,  93.77679311,  85.43554182, 115.32341157,
#         97.70735662, 105.8611145 , 105.05706634,  98.6865532 ,
#        123.17208259, 116.98077511,  89.97689113, 100.62133294,
# ...

# %% [markdown]
# In normal distribution having standard deviation 10, points are more closer to mean i.e. 100 than normal distribution having standard deviation 20.

# %% [markdown]
# #### __Plot the both curves and observe the difference__ (Good Task)

# %%
normal_vals = np.random.normal(100,20,1000)

# %%
plt.figure(figsize=(15,7)) 
sns.distplot(normal_vals)

# %%
normal_vals = np.random.normal(100,10,1000)

# %%
plt.figure(figsize=(15,7)) 
sns.distplot(normal_vals)

# %% [markdown]
# The curve having standard deviation 20 is more wider and shorter as compare to the curve having standard deviation 10.

# %% [markdown]
# #### __Find 3 type of more distributions and explain them here other than normal distribution. Try to plot them it only takes 2 easy lines:__
# import matplotlib.pyplot as plt<br>
# import seaborn as sns
#
#
# plt.figure(figsize=(15,7)) #<================ This line sets the figure size so use it before every figure plotting<br>
# sns.distplot(normal_vals) #<====== this create a plot (kind of histogram) for the values just put whatever variable you have
#
# plug your values in normal_vals and you will have your histogram

# %% [markdown]
# Binomial Distribution - A distribution where only two outcomes are possible, such as success or failure and where the probability of success and failure is same for all the trials is called a Binomial Distribution.

# %%
normal_vals = np.random.binomial(10,0.1,1000) # 10 is no. of trials, 0.1 is probability

# %%
plt.figure(figsize=(15,7)) 
sns.distplot(normal_vals)

# %% [markdown]
# Poisson Distribution - When the number of trials are much greater then we use Poisson Distribution. It is applicable in situations where events occur at random points of time and space.

# %%
normal_vals = np.random.poisson(5, 10000) # 5 is mean

# %%
plt.figure(figsize=(15,7)) 
sns.distplot(normal_vals)

# %% [markdown]
# Bernoulli Distribution - A Bernoulli distribution has only two possible outcomes, namely 1 (success) and 0 (failure), and a single trial.

# %%
normal_vals = np.random.geometric(0.35, 10000) #0.35 is probability

# %%
plt.figure(figsize=(15,7)) 
sns.distplot(normal_vals)
